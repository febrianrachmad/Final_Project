# %%
#Import the usual library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import warnings
warnings.filterwarnings('ignore')

# %%
dfyamaha = pd.read_excel('Penjualan_Motor_20052018.xlsx', index_col = 0)

# %%
dfyamaha
# Out:
#              Honda  Yamaha  Suzuki  Kawasaki  Others   Total
# Periode
# 2005-01-01  208204   83114   83846      7701    4218  387083
# 2005-02-01  192320   78640   82381      6821    3244  363406
# 2005-03-01  217344   79752   96876      4147    2601  400720
# 2005-04-01  205691   94465  100507      3911    3170  407744
# 2005-05-01  219358  104530   87016      5496    3208  419608
# 2005-06-01  241295  120029  104493      7435    3703  476955
# 2005-07-01  238044  117049  106515      7140    3499  472247
# 2005-08-01  256591  120293  115136      9879    2888  504787
# 2005-09-01  237039  101159  102252     10152    2225  452827
# 2005-10-01  283672  108008   90829      5727    2318  490554
# 2005-11-01  188506   95897   60217      3457    1990  350067
# 2005-12-01  160126  121659   61894      2262    2247  348188
# 2006-01-01  116873  105025   39469      3153    2098  266618
# 2006-02-01  167916  123809   32600      3406    3036  330767
# 2006-03-01  145031   93331   32794      3524    1743  276423
# 2006-04-01  140214   93272   33571      2602    1433  271092
# 2006-05-01  170839  111472   37725      1297    1347  322680
# 2006-06-01  171674  122286   46724      1367    1348  343399
# 2006-07-01  186047  131615   47206      3009    2470  370347
# 2006-08-01  241416  136837   56180      3449    2406  440288
# 2006-09-01  276384  143566   67556      3644    2965  494115
# 2006-10-01  174249  109522   55616      2854    2344  344585
# 2006-11-01  293389  156679   67299      3021    3679  524067
# 2006-12-01  255136  131147   51301      2360    3017  442961
# 2007-01-01  153806  130587   52309      2940    3131  342773
# 2007-02-01  150979  145872   46123      2914    2835  348723
# 2007-03-01  151074  159035   47175      3441    3130  363855
# 2007-04-01  138434  128270   41173      3785    3263  314925
# 2007-05-01  169217  168367   32965      2665    3192  376406
# 2007-06-01  159859  154220   50391      2680    3161  370311
# ...            ...     ...     ...       ...     ...     ...
# 2016-07-01  203659   91015    3800      6584      95  305153
# 2016-08-01  388847  123972    6445      8085     187  527536
# 2016-09-01  423256  119717    4628      8036     183  555820
# 2016-10-01  446611  114493    2469      7500     128  571201
# 2016-11-01  450331  107501    4857      8104     130  570923
# 2016-12-01  309796  118078    3510      6262     118  437764
# 2017-01-01  368739   94117    3511      7370     142  473879
# 2017-02-01  345921   93511    5904      8298     129  453763
# 2017-03-01  358524   98040    8600      8601     131  473896
# 2017-04-01  274155  101908    5879      6002     101  388045
# 2017-05-01  394751  122186    8526      5915     118  531496
# 2017-06-01  263854  105133    6270      4143      67  379467
# 2017-07-01  403487  120608    7312      6690      79  538176
# 2017-08-01  418931  123620    6279      6009      84  554923
# 2017-09-01  408116  124360    6823      7224      84  546607
# 2017-10-01  436974  129636    6172      6658     112  579552
# 2017-11-01  430487  109834    3617      6274      91  550303
# 2017-12-01  281949  125258    3298      5453      38  415996
# 2018-01-01  345957  122989    6051      7509      31  482537
# 2018-02-01  339152   85429    4500     10456      49  439586
# 2018-03-01  384187  133126    4077     13969      12  535371
# 2018-04-01  458499  113182    6954      2282       4  580921
# 2018-05-01  436727  140068    7663      4828      18  589304
# 2018-06-01  271206   96150    5357      2302      19  375034
# 2018-07-01  450622  127101    8639      7366      21  593749
# 2018-08-01  443694  108896    8355      7016      95  568056
# 2018-09-01  406841  134419    9371      7036      25  557692
# 2018-10-01  456582  138012   10489      5212      27  610322
# 2018-11-01  440659  140683   10002      6003      17  597364
# 2018-12-01  325076  115033    8050      5003      19  453181
#
# [168 rows x 6 columns]

# %%
dfyamaha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2005-01-01 to 2018-12-01
# Data columns (total 6 columns):
# Honda       168 non-null int64
# Yamaha      168 non-null int64
# Suzuki      168 non-null int64
# Kawasaki    168 non-null int64
# Others      168 non-null int64
# Total       168 non-null int64
# dtypes: int64(6)
# memory usage: 9.2 KB

# %%
print('The data Time range from {} to {}'.format(dfyamaha.index.min(),dfyamaha.index.max()))
# Out:
# The data Time range from 2005-01-01 00:00:00 to 2018-12-01 00:00:00

# %%
y = dfyamaha['Yamaha'].resample('MS').mean()

# %%
y
# Out:
# Periode
# 2005-01-01     83114
# 2005-02-01     78640
# 2005-03-01     79752
# 2005-04-01     94465
# 2005-05-01    104530
# 2005-06-01    120029
# 2005-07-01    117049
# 2005-08-01    120293
# 2005-09-01    101159
# 2005-10-01    108008
# 2005-11-01     95897
# 2005-12-01    121659
# 2006-01-01    105025
# 2006-02-01    123809
# 2006-03-01     93331
# 2006-04-01     93272
# 2006-05-01    111472
# 2006-06-01    122286
# 2006-07-01    131615
# 2006-08-01    136837
# 2006-09-01    143566
# 2006-10-01    109522
# 2006-11-01    156679
# 2006-12-01    131147
# 2007-01-01    130587
# 2007-02-01    145872
# 2007-03-01    159035
# 2007-04-01    128270
# 2007-05-01    168367
# 2007-06-01    154220
#                ...
# 2016-07-01     91015
# 2016-08-01    123972
# 2016-09-01    119717
# 2016-10-01    114493
# 2016-11-01    107501
# 2016-12-01    118078
# 2017-01-01     94117
# 2017-02-01     93511
# 2017-03-01     98040
# 2017-04-01    101908
# 2017-05-01    122186
# 2017-06-01    105133
# 2017-07-01    120608
# 2017-08-01    123620
# 2017-09-01    124360
# 2017-10-01    129636
# 2017-11-01    109834
# 2017-12-01    125258
# 2018-01-01    122989
# 2018-02-01     85429
# 2018-03-01    133126
# 2018-04-01    113182
# 2018-05-01    140068
# 2018-06-01     96150
# 2018-07-01    127101
# 2018-08-01    108896
# 2018-09-01    134419
# 2018-10-01    138012
# 2018-11-01    140683
# 2018-12-01    115033
# Freq: MS, Name: Yamaha, Length: 168, dtype: int64

# %%
y.head()
# Out:
# Periode
# 2005-01-01     83114
# 2005-02-01     78640
# 2005-03-01     79752
# 2005-04-01     94465
# 2005-05-01    104530
# Freq: MS, Name: Yamaha, dtype: int64

# %%
y.isna().any()
# Out:
# False

# %%
plt.figure(figsize = (18,8))
plt.title('Monthly Average of Motor yamaha Sale')
y.plot()

# EXPONENSIAL

# %%
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='multipicative')
fig = decomposition.plot()
plt.show()

# %%
decomposition.trend
# Out:
# Periode
# 2005-01-01              NaN
# 2005-02-01              NaN
# 2005-03-01              NaN
# 2005-04-01              NaN
# 2005-05-01              NaN
# 2005-06-01              NaN
# 2005-07-01    102962.541667
# 2005-08-01    105757.541667
# 2005-09-01    108205.375000
# 2005-10-01    108721.458333
# 2005-11-01    108961.000000
# 2005-12-01    109344.291667
# 2006-01-01    110045.250000
# 2006-02-01    111341.500000
# 2006-03-01    113797.791667
# 2006-04-01    115627.833333
# 2006-05-01    118223.500000
# 2006-06-01    121151.416667
# 2006-07-01    122611.833333
# 2006-08-01    124596.208333
# 2006-09-01    128253.166667
# 2006-10-01    132449.083333
# 2006-11-01    136277.958333
# 2006-12-01    139979.166667
# 2007-01-01    142536.666667
# 2007-02-01    145029.041667
# 2007-03-01    147089.208333
# 2007-04-01    149441.666667
# 2007-05-01    151724.708333
# 2007-06-01    152693.791667
#                   ...
# 2016-07-01    115422.875000
# 2016-08-01    112767.416667
# 2016-09-01    110429.916667
# 2016-10-01    109237.166667
# 2016-11-01    108895.125000
# 2016-12-01    108393.041667
# 2017-01-01    108705.625000
# 2017-02-01    109924.000000
# 2017-03-01    110102.791667
# 2017-04-01    110927.208333
# 2017-05-01    111655.375000
# 2017-06-01    112051.750000
# 2017-07-01    113553.916667
# 2017-08-01    114420.166667
# 2017-09-01    115545.333333
# 2017-10-01    117477.000000
# 2017-11-01    118691.833333
# 2017-12-01    119062.625000
# 2018-01-01    118958.875000
# 2018-02-01    118615.916667
# 2018-03-01    118421.541667
# 2018-04-01    119189.666667
# 2018-05-01    120824.041667
# 2018-06-01    121683.375000
# 2018-07-01              NaN
# 2018-08-01              NaN
# 2018-09-01              NaN
# 2018-10-01              NaN
# 2018-11-01              NaN
# 2018-12-01              NaN
# Freq: MS, Name: Yamaha, Length: 168, dtype: float64

# %%
#import the Augmented Dickey-Fuller Test

from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(y)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-1.432295270094436
# p-value: 0.5666992135166101

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})

# Original Series
ori = y.plot()
ori.set_title('Original Series')
plot_acf(y, title = 'Autocorellation original')

plt.show()

# %%
# 1st Differencing
diff1 = y.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_acf(y.diff().dropna(),lags =30,  title = 'Autocorellation Differenced 1')

plt.show()

# %%
# 2nd Differencing
diff2 = y.diff().diff().dropna().plot()
diff2.set_title('Time Series Differenced 2')
plot_acf(y.diff().diff().dropna(),lags = 30, title = 'Autocorellation Differenced 2')

plt.show()

# %%
# 12ve Differencing
diff12 = y.diff(12).dropna().plot()
diff12.set_title('Time Series Differenced 12')
plot_acf(y.diff(12).dropna(),lags = 30, title = 'Autocorellation Differenced 12')

plt.show()

# %%
result = adfuller(y.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-2.5813090443498843
# p-value: 0.09692216731283448

# %%
result = adfuller(y.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-7.198351584015466
# p-value: 2.4015277213111295e-10

# %%
result = adfuller(y.diff(12).dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-3.3568628169905033
# p-value: 0.012520313760223986

# %%
y_difference_2 = y.diff().diff().dropna()

# %%
#We are using the Additive model because the plot look like it was following the addition model
decomposition_difference_2 = sm.tsa.seasonal_decompose(y_difference_2, model='additive') 
fig = decomposition_difference_2.plot()
plt.show()

# %%
y_deseason = y_difference_2/ decomposition_difference_2.seasonal

# %%
#Deseason original
ori_deseason = y_deseason.plot()
ori_deseason.set_title('Deseason Original')
plot_acf(y_deseason, title = 'Deseason original Autocorellation')

plt.show()

# %%
result = adfuller(y_deseason)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-12.707613570696243
# p-value: 1.0468045090337938e-23

# %%
# 1st Differencing
diff1_deseason = y_deseason.diff().dropna().plot()
diff1_deseason.set_title('Time Series Deseason Differenced 1')
plot_acf(y_deseason.diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 1')

plt.show()

# %%
result = adfuller(y_deseason.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-9.75175778017395
# p-value: 7.981285431656637e-17

# %%
# 2nd Differencing
diff2_deseason = y_deseason.diff().diff().dropna().plot()
diff2_deseason.set_title('Time Series Deseason Differenced 2')
plot_acf(y_deseason.diff().diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 2')

plt.show()

# %%
result = adfuller(y_deseason.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-9.378682783575057
# p-value: 7.053037390322097e-16

# %%
#PACF
diff1 = y_deseason.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_pacf(y_deseason.diff().dropna(), lags = 30, title = 'Partial Autocorellation Differenced 1')

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(y_deseason,order =(1,1,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D.Yamaha   No. Observations:                  165
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -941.825
# Method:                       css-mle   S.D. of innovations             71.784
# Date:                Fri, 22 Nov 2019   AIC                           1891.649
# Time:                        15:25:21   BIC                           1904.073
# Sample:                    04-01-2005   HQIC                          1896.693
#                          - 12-01-2018
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0394      0.117      0.335      0.738      -0.191       0.270
# ar.L1.D.Yamaha     0.0103      0.078      0.133      0.895      -0.142       0.163
# ma.L1.D.Yamaha    -1.0000      0.024    -41.298      0.000      -1.047      -0.953
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           96.7955           +0.0000j           96.7955            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
plt.rcParams.update({'figure.figsize':(12,3), 'figure.dpi':120})
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
#Data split by close to 1:4 ratio

train = y_deseason[:125]
test = y_deseason[125:]

# %%
n_periods = 24
model = ARIMA(train, order=(1, 1, 1))  
fitted = model.fit(disp=-1)  

# Forecast (resulted in forecast, standard error, and confidence interval)
fc, se, conf = fitted.forecast(41, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    
    mins = np.amin(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
  
    return({'mape':mape,'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test)
# Out:
# {'mape': 3.8013342826279617,
#  'corr': 0.29804921731269124,
#  'minmax': 9.769233514409162}

# %%
import pmdarima as pm

model = pm.auto_arima(y_deseason, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series (1 as monthly)
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# Fit ARIMA: order=(1, 0, 1); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 0); AIC=1893.053, BIC=1899.277, Fit time=0.003 seconds
# Fit ARIMA: order=(1, 0, 0); AIC=1895.048, BIC=1904.384, Fit time=0.017 seconds
# Fit ARIMA: order=(0, 0, 1); AIC=1895.049, BIC=1904.384, Fit time=0.020 seconds
# Total fit time: 0.057 seconds
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  166
# Model:                     ARMA(0, 0)   Log Likelihood                -944.526
# Method:                           css   S.D. of innovations             71.592
# Date:                Fri, 22 Nov 2019   AIC                           1893.053
# Time:                        15:25:23   BIC                           1899.277
# Sample:                             0   HQIC                          1895.579
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4039      5.557      0.253      0.801      -9.487      12.295
# ==============================================================================
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
model.plot_diagnostics(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(y, label='Original Series')
axes[0].plot(y.diff(), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)

# Seasonal Differencing
axes[1].plot(y, label='Original Series')
axes[1].plot(y.diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('Motor Yamaha Sales', fontsize=16)
plt.show()

# %%
model = pm.auto_arima(y, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=5, max_q=5, # maximum p and q
                      m=12,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # with Seasonality
                      start_P=0, 
                      start_Q = 0, 
                      D=1,            #Determine the Seasonal Difference as 1
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=3709.419, BIC=3715.506, Fit time=0.022 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=3659.601, BIC=3671.775, Fit time=0.136 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=3647.640, BIC=3659.814, Fit time=0.562 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=3639.539, BIC=3654.756, Fit time=0.390 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 0, 12); AIC=3658.185, BIC=3670.358, Fit time=0.206 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=3641.451, BIC=3659.711, Fit time=0.752 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=3666.046, BIC=3675.176, Fit time=0.049 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=3641.229, BIC=3662.533, Fit time=1.554 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=3639.216, BIC=3657.477, Fit time=0.346 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 1, 12); AIC=3640.613, BIC=3655.830, Fit time=0.369 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=3637.485, BIC=3658.789, Fit time=0.712 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=3639.358, BIC=3666.749, Fit time=1.317 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3646.432, BIC=3664.693, Fit time=0.443 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=3639.483, BIC=3663.830, Fit time=1.258 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=3654.538, BIC=3672.798, Fit time=0.440 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=3639.485, BIC=3663.832, Fit time=1.060 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=3664.054, BIC=3679.271, Fit time=0.129 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=3639.635, BIC=3667.026, Fit time=2.602 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=3640.805, BIC=3659.065, Fit time=0.371 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=3637.305, BIC=3661.653, Fit time=0.738 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=3637.984, BIC=3659.288, Fit time=0.652 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(1, 1, 1, 12); AIC=3639.243, BIC=3669.678, Fit time=1.939 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=3647.119, BIC=3668.423, Fit time=0.647 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 1, 1, 12); AIC=3639.298, BIC=3666.689, Fit time=1.885 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 0, 12); AIC=3655.289, BIC=3676.593, Fit time=0.669 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=3639.305, BIC=3666.696, Fit time=1.780 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=3661.217, BIC=3679.478, Fit time=0.276 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(2, 1, 2, 12); AIC=3639.087, BIC=3669.521, Fit time=2.757 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=3639.259, BIC=3666.650, Fit time=1.006 seconds
# Total fit time: 25.084 seconds
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(2, 1, 2)x(1, 1, 1, 12)   Log Likelihood               -1810.653
# Date:                            Fri, 22 Nov 2019   AIC                           3637.305
# Time:                                    15:25:49   BIC                           3661.653
# Sample:                                         0   HQIC                          3647.195
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   -108.9931    501.263     -0.217      0.828   -1091.450     873.463
# ar.L1         -0.6759      0.386     -1.750      0.080      -1.433       0.081
# ar.L2          0.1652      0.203      0.814      0.416      -0.232       0.563
# ma.L1          0.1118      0.377      0.296      0.767      -0.627       0.851
# ma.L2         -0.4639      0.185     -2.503      0.012      -0.827      -0.101
# ar.S.L12       0.3912      0.158      2.471      0.013       0.081       0.701
# ma.S.L12      -0.9150      0.183     -4.989      0.000      -1.274      -0.556
# sigma2      1.014e+09      0.000   2.57e+12      0.000    1.01e+09    1.01e+09
# ===================================================================================
# Ljung-Box (Q):                       58.98   Jarque-Bera (JB):                 2.30
# Prob(Q):                              0.03   Prob(JB):                         0.32
# Heteroskedasticity (H):               0.81   Skew:                            -0.19
# Prob(H) (two-sided):                  0.45   Kurtosis:                         3.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.03e+28. Standard errors may be unstable.

# %%
model.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
n_periods = 24
train = y[:125]
test = y[125:]

fitted, confint = model.predict(n_periods=n_periods, return_conf_int=True) #Return the Confidence Interval
index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train, label ='Training')
plt.plot(test, label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast of Motor Yamaha Sales")
plt.show()

# %%
fitted
# Out:
# array([128675.07005608, 107375.43445411, 140057.83565227, 124609.15070063,
#        143622.887096  , 116766.94950442, 134298.44501946, 121708.14429179,
#        134777.41540797, 137189.09305226, 134478.22265209, 113707.84905642,
#        124680.79726669, 115811.32608975, 136940.50525165, 127982.75701503,
#        139671.47052071, 123031.66643805, 132109.74483757, 124357.4014251 ,
#        130131.63566059, 134046.65344702, 127392.97102233, 109988.92948492])

# %%
confint
# Out:
# array([[ 6.59605005e+04,  1.91389640e+05],
#        [ 3.89663929e+04,  1.75784476e+05],
#        [ 6.43144964e+04,  2.15801175e+05],
#        [ 4.54045380e+04,  2.03813763e+05],
#        [ 5.88074874e+04,  2.28438287e+05],
#        [ 2.86356685e+04,  2.04898230e+05],
#        [ 4.13789445e+04,  2.27217946e+05],
#        [ 2.55660918e+04,  2.17850197e+05],
#        [ 3.44149077e+04,  2.35139923e+05],
#        [ 3.37001027e+04,  2.40678083e+05],
#        [ 2.71827510e+04,  2.41773694e+05],
#        [ 3.37515254e+03,  2.24040546e+05],
#        [-1.52411566e+02,  2.49514006e+05],
#        [-1.50279637e+04,  2.46650616e+05],
#        [-9.25545484e+02,  2.74806556e+05],
#        [-1.48664832e+04,  2.70831997e+05],
#        [-9.27679486e+03,  2.88619736e+05],
#        [-3.06789107e+04,  2.76742244e+05],
#        [-2.71292399e+04,  2.91348730e+05],
#        [-3.94604438e+04,  2.88175247e+05],
#        [-3.87780526e+04,  2.99041324e+05],
#        [-3.92720273e+04,  3.07365334e+05],
#        [-5.06765218e+04,  3.05462464e+05],
#        [-7.23518069e+04,  2.92329666e+05]])

# %%
#Decompose the time series data to get the seasonal data. Lets try to take 36 months back in the past as exogenous variable

# multiplicative seasonal component
result_mul = sm.tsa.seasonal_decompose(y[-36:],   # 36 months
                                model='multiplicative', 
                                extrapolate_trend='freq')

# %%
plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})
fig = result_mul.plot()
plt.show()

# %%
#We would use what we called seasonal index as our exogenous varibale. We take the latest 12 month.
seasonal_index = result_mul.seasonal[-12:].to_frame()
seasonal_index['month'] = pd.to_datetime(seasonal_index.index).month

# %%
#lets merge it into one dataframe
y = pd.DataFrame(y)
y['month'] = y.index.month
df = pd.merge(y, seasonal_index, how='left', on='month')
df.columns = ['Yamaha', 'month', 'seasonal_index']
df.index = y.index  # reassign the index.

# %%
df.head()
# Out:
#             Yamaha  month  seasonal_index
# Periode
# 2005-01-01   83114      1        0.957898
# 2005-02-01   78640      2        0.929602
# 2005-03-01   79752      3        0.985663
# 2005-04-01   94465      4        0.972386
# 2005-05-01  104530      5        1.076368

# %%
sxmodel = pm.auto_arima(df[['Yamaha']], exogenous=df[['seasonal_index']],
                           start_p=1, start_q=1,
                           test='adf',
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=None, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)

sxmodel.summary()
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=3673.717, BIC=3692.016, Fit time=0.429 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=3794.265, BIC=3803.414, Fit time=0.014 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=3709.618, BIC=3724.867, Fit time=0.149 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=3758.971, BIC=3774.220, Fit time=0.158 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3664.574, BIC=3685.923, Fit time=0.517 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 0, 12); AIC=3682.619, BIC=3700.918, Fit time=0.194 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=3666.487, BIC=3690.886, Fit time=1.092 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=3689.276, BIC=3704.525, Fit time=0.071 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 1, 2, 12); AIC=3667.597, BIC=3695.046, Fit time=2.545 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3760.611, BIC=3778.910, Fit time=0.337 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3663.840, BIC=3688.239, Fit time=0.984 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=3665.425, BIC=3686.774, Fit time=0.610 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 1, 1, 12); AIC=3663.079, BIC=3690.528, Fit time=0.813 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 1, 1, 12); AIC=3664.826, BIC=3698.374, Fit time=1.762 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 1, 1, 12); AIC=3672.181, BIC=3696.580, Fit time=0.432 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 1, 1, 12); AIC=3665.077, BIC=3695.576, Fit time=1.626 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 1, 0, 12); AIC=3678.772, BIC=3703.171, Fit time=0.365 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 1, 2, 12); AIC=3665.079, BIC=3695.577, Fit time=1.570 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 1, 0, 12); AIC=3685.998, BIC=3707.347, Fit time=0.127 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 1, 2, 12); AIC=3667.005, BIC=3700.554, Fit time=1.817 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(1, 1, 1, 12); AIC=3667.196, BIC=3691.595, Fit time=0.833 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 1, 1, 12); AIC=3669.915, BIC=3700.414, Fit time=1.880 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 1, 1, 12); AIC=3664.830, BIC=3695.329, Fit time=0.929 seconds
# Total fit time: 19.273 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(2, 0, 2)x(1, 1, 1, 12)   Log Likelihood               -1822.540
# Date:                            Fri, 22 Nov 2019   AIC                           3663.079
# Time:                                    15:26:12   BIC                           3690.528
# Sample:                                         0   HQIC                          3674.228
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    175.1698    568.243      0.308      0.758    -938.566    1288.906
# x1             0.0003   2.43e+04   1.07e-08      1.000   -4.77e+04    4.77e+04
# ar.L1          0.0853      0.204      0.419      0.675      -0.314       0.484
# ar.L2          0.8609      0.216      3.981      0.000       0.437       1.285
# ma.L1          0.2743      0.230      1.194      0.233      -0.176       0.725
# ma.L2         -0.4195      0.199     -2.112      0.035      -0.809      -0.030
# ar.S.L12       0.3764      0.159      2.370      0.018       0.065       0.688
# ma.S.L12      -0.9193      0.175     -5.265      0.000      -1.261      -0.577
# sigma2      9.937e+08      0.675   1.47e+09      0.000    9.94e+08    9.94e+08
# ===================================================================================
# Ljung-Box (Q):                       52.55   Jarque-Bera (JB):                 2.26
# Prob(Q):                              0.09   Prob(JB):                         0.32
# Heteroskedasticity (H):               0.69   Skew:                            -0.18
# Prob(H) (two-sided):                  0.19   Kurtosis:                         3.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.36e+24. Standard errors may be unstable.
# """

# %%
train = df[:150]
test = df[150:]

fitted, confint = sxmodel.predict(n_periods=n_periods, 
                                  exogenous=np.tile(seasonal_index['Yamaha'], 2).reshape(-1,1), 
                                  return_conf_int=True,alpha=0.05)

index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train['Yamaha'], label ='Training')
plt.plot(test['Yamaha'], label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMAX - Final Forecast of Motor Yamaha Sales with Exogenous Variable")
plt.show()

# %%
fitted
# Out:
# array([133016.08549677, 114042.63001826, 146337.15487964, 132463.82015409,
#        151828.80376525, 126517.60178252, 144635.33925466, 132826.55411273,
#        146465.11583   , 149224.21371296, 147530.71103551, 126090.30550667,
#        142003.66616037, 135213.94458756, 156860.67813592, 149325.119898  ,
#        162029.03907083, 146883.15681427, 157143.10217065, 150205.9074073 ,
#        156975.15512504, 161337.52276826, 156101.76704918, 137734.07395278])

# %%
confint
# Out:
# array([[ 70894.23240876, 195137.93858479],
#        [ 48041.07959156, 180044.18044496],
#        [ 74141.04436222, 218533.26539706],
#        [ 57086.36444662, 207841.27586156],
#        [ 71757.90054176, 231899.70698875],
#        [ 43756.13793602, 209279.06562903],
#        [ 58178.31735327, 231092.36115606],
#        [ 44058.93227292, 221594.17595253],
#        [ 54714.41464976, 238215.81701024],
#        [ 55472.61063175, 242975.81679417],
#        [ 51329.26079789, 243732.16127313],
#        [ 28147.91275857, 224032.69825477],
#        [ 32426.72552205, 251580.60679868],
#        [ 22123.62827239, 248304.26090272],
#        [ 39197.02923468, 274524.32703715],
#        [ 28644.89796158, 270005.34183443],
#        [ 37624.87842534, 286433.19971632],
#        [ 19868.65111255, 273897.662516  ],
#        [ 27048.70985643, 287237.49448486],
#        [ 17842.15944591, 282569.6553687 ],
#        [ 22035.23979621, 291915.07045387],
#        [ 24419.22918551, 298255.816351  ],
#        [ 17010.98531979, 295192.54877857],
#        [ -3084.08211082, 278552.23001637]])

# %%
#Import the usual library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import warnings
warnings.filterwarnings('ignore')

# %%
dfkawasaki = pd.read_excel('Penjualan_Motor_20052018.xlsx', index_col = 0)

# %%
dfkawasaki
# Out:
#              Honda  Yamaha  Suzuki  Kawasaki  Others   Total
# Periode
# 2005-01-01  208204   83114   83846      7701    4218  387083
# 2005-02-01  192320   78640   82381      6821    3244  363406
# 2005-03-01  217344   79752   96876      4147    2601  400720
# 2005-04-01  205691   94465  100507      3911    3170  407744
# 2005-05-01  219358  104530   87016      5496    3208  419608
# 2005-06-01  241295  120029  104493      7435    3703  476955
# 2005-07-01  238044  117049  106515      7140    3499  472247
# 2005-08-01  256591  120293  115136      9879    2888  504787
# 2005-09-01  237039  101159  102252     10152    2225  452827
# 2005-10-01  283672  108008   90829      5727    2318  490554
# 2005-11-01  188506   95897   60217      3457    1990  350067
# 2005-12-01  160126  121659   61894      2262    2247  348188
# 2006-01-01  116873  105025   39469      3153    2098  266618
# 2006-02-01  167916  123809   32600      3406    3036  330767
# 2006-03-01  145031   93331   32794      3524    1743  276423
# 2006-04-01  140214   93272   33571      2602    1433  271092
# 2006-05-01  170839  111472   37725      1297    1347  322680
# 2006-06-01  171674  122286   46724      1367    1348  343399
# 2006-07-01  186047  131615   47206      3009    2470  370347
# 2006-08-01  241416  136837   56180      3449    2406  440288
# 2006-09-01  276384  143566   67556      3644    2965  494115
# 2006-10-01  174249  109522   55616      2854    2344  344585
# 2006-11-01  293389  156679   67299      3021    3679  524067
# 2006-12-01  255136  131147   51301      2360    3017  442961
# 2007-01-01  153806  130587   52309      2940    3131  342773
# 2007-02-01  150979  145872   46123      2914    2835  348723
# 2007-03-01  151074  159035   47175      3441    3130  363855
# 2007-04-01  138434  128270   41173      3785    3263  314925
# 2007-05-01  169217  168367   32965      2665    3192  376406
# 2007-06-01  159859  154220   50391      2680    3161  370311
# ...            ...     ...     ...       ...     ...     ...
# 2016-07-01  203659   91015    3800      6584      95  305153
# 2016-08-01  388847  123972    6445      8085     187  527536
# 2016-09-01  423256  119717    4628      8036     183  555820
# 2016-10-01  446611  114493    2469      7500     128  571201
# 2016-11-01  450331  107501    4857      8104     130  570923
# 2016-12-01  309796  118078    3510      6262     118  437764
# 2017-01-01  368739   94117    3511      7370     142  473879
# 2017-02-01  345921   93511    5904      8298     129  453763
# 2017-03-01  358524   98040    8600      8601     131  473896
# 2017-04-01  274155  101908    5879      6002     101  388045
# 2017-05-01  394751  122186    8526      5915     118  531496
# 2017-06-01  263854  105133    6270      4143      67  379467
# 2017-07-01  403487  120608    7312      6690      79  538176
# 2017-08-01  418931  123620    6279      6009      84  554923
# 2017-09-01  408116  124360    6823      7224      84  546607
# 2017-10-01  436974  129636    6172      6658     112  579552
# 2017-11-01  430487  109834    3617      6274      91  550303
# 2017-12-01  281949  125258    3298      5453      38  415996
# 2018-01-01  345957  122989    6051      7509      31  482537
# 2018-02-01  339152   85429    4500     10456      49  439586
# 2018-03-01  384187  133126    4077     13969      12  535371
# 2018-04-01  458499  113182    6954      2282       4  580921
# 2018-05-01  436727  140068    7663      4828      18  589304
# 2018-06-01  271206   96150    5357      2302      19  375034
# 2018-07-01  450622  127101    8639      7366      21  593749
# 2018-08-01  443694  108896    8355      7016      95  568056
# 2018-09-01  406841  134419    9371      7036      25  557692
# 2018-10-01  456582  138012   10489      5212      27  610322
# 2018-11-01  440659  140683   10002      6003      17  597364
# 2018-12-01  325076  115033    8050      5003      19  453181
#
# [168 rows x 6 columns]

# %%
dfkawasaki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2005-01-01 to 2018-12-01
# Data columns (total 6 columns):
# Honda       168 non-null int64
# Yamaha      168 non-null int64
# Suzuki      168 non-null int64
# Kawasaki    168 non-null int64
# Others      168 non-null int64
# Total       168 non-null int64
# dtypes: int64(6)
# memory usage: 9.2 KB

# %%
print('The data Time range from {} to {}'.format(dfkawasaki.index.min(),dfkawasaki.index.max()))
# Out:
# The data Time range from 2005-01-01 00:00:00 to 2018-12-01 00:00:00

# %%
y = dfkawasaki['Kawasaki'].resample('MS').mean()

# %%
y
# Out:
# Periode
# 2005-01-01     7701
# 2005-02-01     6821
# 2005-03-01     4147
# 2005-04-01     3911
# 2005-05-01     5496
# 2005-06-01     7435
# 2005-07-01     7140
# 2005-08-01     9879
# 2005-09-01    10152
# 2005-10-01     5727
# 2005-11-01     3457
# 2005-12-01     2262
# 2006-01-01     3153
# 2006-02-01     3406
# 2006-03-01     3524
# 2006-04-01     2602
# 2006-05-01     1297
# 2006-06-01     1367
# 2006-07-01     3009
# 2006-08-01     3449
# 2006-09-01     3644
# 2006-10-01     2854
# 2006-11-01     3021
# 2006-12-01     2360
# 2007-01-01     2940
# 2007-02-01     2914
# 2007-03-01     3441
# 2007-04-01     3785
# 2007-05-01     2665
# 2007-06-01     2680
#               ...
# 2016-07-01     6584
# 2016-08-01     8085
# 2016-09-01     8036
# 2016-10-01     7500
# 2016-11-01     8104
# 2016-12-01     6262
# 2017-01-01     7370
# 2017-02-01     8298
# 2017-03-01     8601
# 2017-04-01     6002
# 2017-05-01     5915
# 2017-06-01     4143
# 2017-07-01     6690
# 2017-08-01     6009
# 2017-09-01     7224
# 2017-10-01     6658
# 2017-11-01     6274
# 2017-12-01     5453
# 2018-01-01     7509
# 2018-02-01    10456
# 2018-03-01    13969
# 2018-04-01     2282
# 2018-05-01     4828
# 2018-06-01     2302
# 2018-07-01     7366
# 2018-08-01     7016
# 2018-09-01     7036
# 2018-10-01     5212
# 2018-11-01     6003
# 2018-12-01     5003
# Freq: MS, Name: Kawasaki, Length: 168, dtype: int64

# %%
y.head()
# Out:
# Periode
# 2005-01-01    7701
# 2005-02-01    6821
# 2005-03-01    4147
# 2005-04-01    3911
# 2005-05-01    5496
# Freq: MS, Name: Kawasaki, dtype: int64

# %%
y.isna().any()
# Out:
# False

# %%
plt.figure(figsize = (18,8))
plt.title('Monthly Average of Motor kawasaki Sale')
y.plot()

# EXPONENSIAL

# %%
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='multipicative')
fig = decomposition.plot()
plt.show()

# %%
decomposition.trend
# Out:
# Periode
# 2005-01-01            NaN
# 2005-02-01            NaN
# 2005-03-01            NaN
# 2005-04-01            NaN
# 2005-05-01            NaN
# 2005-06-01            NaN
# 2005-07-01    5987.833333
# 2005-08-01    5656.041667
# 2005-09-01    5487.791667
# 2005-10-01    5407.291667
# 2005-11-01    5177.791667
# 2005-12-01    4750.000000
# 2006-01-01    4325.041667
# 2006-02-01    3885.000000
# 2006-03-01    3345.916667
# 2006-04-01    2955.041667
# 2006-05-01    2817.166667
# 2006-06-01    2803.083333
# 2006-07-01    2798.291667
# 2006-08-01    2768.916667
# 2006-09-01    2744.958333
# 2006-10-01    2790.791667
# 2006-11-01    2897.083333
# 2006-12-01    3008.791667
# 2007-01-01    3070.916667
# 2007-02-01    3084.041667
# 2007-03-01    3095.958333
# 2007-04-01    3071.250000
# 2007-05-01    3027.666667
# 2007-06-01    3096.416667
#                  ...
# 2016-07-01    7997.208333
# 2016-08-01    7743.291667
# 2016-09-01    7590.625000
# 2016-10-01    7504.416667
# 2016-11-01    7413.500000
# 2016-12-01    7223.541667
# 2017-01-01    7079.416667
# 2017-02-01    6997.333333
# 2017-03-01    6877.000000
# 2017-04-01    6808.083333
# 2017-05-01    6696.750000
# 2017-06-01    6586.791667
# 2017-07-01    6558.875000
# 2017-08-01    6654.583333
# 2017-09-01    6968.166667
# 2017-10-01    7036.833333
# 2017-11-01    6836.541667
# 2017-12-01    6714.541667
# 2018-01-01    6666.000000
# 2018-02-01    6736.125000
# 2018-03-01    6770.250000
# 2018-04-01    6702.166667
# 2018-05-01    6630.625000
# 2018-06-01    6600.583333
# 2018-07-01            NaN
# 2018-08-01            NaN
# 2018-09-01            NaN
# 2018-10-01            NaN
# 2018-11-01            NaN
# 2018-12-01            NaN
# Freq: MS, Name: Kawasaki, Length: 168, dtype: float64

# %%
#import the Augmented Dickey-Fuller Test

from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(y)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-1.3084634243352984
# p-value: 0.62529144640874

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})

# Original Series
ori = y.plot()
ori.set_title('Original Series')
plot_acf(y, title = 'Autocorellation original')

plt.show()

# %%
# 1st Differencing
diff1 = y.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_acf(y.diff().dropna(),lags =30,  title = 'Autocorellation Differenced 1')

plt.show()

# %%
# 2nd Differencing
diff2 = y.diff().diff().dropna().plot()
diff2.set_title('Time Series Differenced 2')
plot_acf(y.diff().diff().dropna(),lags = 30, title = 'Autocorellation Differenced 2')

plt.show()

# %%
# 12ve Differencing
diff12 = y.diff(12).dropna().plot()
diff12.set_title('Time Series Differenced 12')
plot_acf(y.diff(12).dropna(),lags = 30, title = 'Autocorellation Differenced 12')

plt.show()

# %%
result = adfuller(y.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-9.86515986398632
# p-value: 4.1326764622106976e-17

# %%
result = adfuller(y.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-7.091419587702389
# p-value: 4.400211548274997e-10

# %%
result = adfuller(y.diff(12).dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-3.1964714829044074
# p-value: 0.02018983429099888

# %%
y_difference_2 = y.diff().diff().dropna()

# %%
#We are using the Additive model because the plot look like it was following the addition model
decomposition_difference_2 = sm.tsa.seasonal_decompose(y_difference_2, model='additive') 
fig = decomposition_difference_2.plot()
plt.show()

# %%
y_deseason = y_difference_2/ decomposition_difference_2.seasonal

# %%
#Deseason original
ori_deseason = y_deseason.plot()
ori_deseason.set_title('Deseason Original')
plot_acf(y_deseason, title = 'Deseason original Autocorellation')

plt.show()

# %%
result = adfuller(y_deseason)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-13.453024743115764
# p-value: 3.6525468414091144e-25

# %%
# 1st Differencing
diff1_deseason = y_deseason.diff().dropna().plot()
diff1_deseason.set_title('Time Series Deseason Differenced 1')
plot_acf(y_deseason.diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 1')

plt.show()

# %%
result = adfuller(y_deseason.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-8.2050747315
# p-value: 7.060455851495273e-13

# %%
# 2nd Differencing
diff2_deseason = y_deseason.diff().diff().dropna().plot()
diff2_deseason.set_title('Time Series Deseason Differenced 2')
plot_acf(y_deseason.diff().diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 2')

plt.show()

# %%
result = adfuller(y_deseason.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-7.5945951172840465
# p-value: 2.4795951177995254e-11

# %%
#PACF
diff1 = y_deseason.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_pacf(y_deseason.diff().dropna(), lags = 30, title = 'Partial Autocorellation Differenced 1')

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(y_deseason,order =(1,1,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:             D.Kawasaki   No. Observations:                  165
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -688.025
# Method:                       css-mle   S.D. of innovations             15.412
# Date:                Fri, 22 Nov 2019   AIC                           1384.050
# Time:                        15:32:53   BIC                           1396.474
# Sample:                    04-01-2005   HQIC                          1389.093
#                          - 12-01-2018
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0064      0.024      0.270      0.787      -0.040       0.053
# ar.L1.D.Kawasaki    -0.0478      0.078     -0.614      0.540      -0.200       0.105
# ma.L1.D.Kawasaki    -1.0000      0.046    -21.700      0.000      -1.090      -0.910
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -20.9212           +0.0000j           20.9212            0.5000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
plt.rcParams.update({'figure.figsize':(12,3), 'figure.dpi':120})
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
#Data split by close to 1:4 ratio

train = y_deseason[:125]
test = y_deseason[125:]

# %%
n_periods = 24
model = ARIMA(train, order=(1, 1, 1))  
fitted = model.fit(disp=-1)  

# Forecast (resulted in forecast, standard error, and confidence interval)
fc, se, conf = fitted.forecast(41, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    
    mins = np.amin(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
  
    return({'mape':mape,'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test)
# Out:
# {'mape': 1.5073603874579857,
#  'corr': -0.36695055525922354,
#  'minmax': -1.121239378792581}

# %%
import pmdarima as pm

model = pm.auto_arima(y_deseason, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series (1 as monthly)
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# Fit ARIMA: order=(1, 0, 1); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 0); AIC=1382.688, BIC=1388.912, Fit time=0.001 seconds
# Fit ARIMA: order=(1, 0, 0); AIC=1384.219, BIC=1393.555, Fit time=0.012 seconds
# Fit ARIMA: order=(0, 0, 1); AIC=1384.128, BIC=1393.464, Fit time=0.015 seconds
# Total fit time: 0.043 seconds
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  166
# Model:                     ARMA(0, 0)   Log Likelihood                -689.344
# Method:                           css   S.D. of innovations             15.390
# Date:                Fri, 22 Nov 2019   AIC                           1382.688
# Time:                        15:32:55   BIC                           1388.912
# Sample:                             0   HQIC                          1385.214
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2492      1.195      1.046      0.297      -1.092       3.590
# ==============================================================================
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
model.plot_diagnostics(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(y, label='Original Series')
axes[0].plot(y.diff(), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)

# Seasonal Differencing
axes[1].plot(y, label='Original Series')
axes[1].plot(y.diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('Motor Kawasaki Sales', fontsize=16)
plt.show()

# %%
model = pm.auto_arima(y, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=5, max_q=5, # maximum p and q
                      m=12,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # with Seasonality
                      start_P=0, 
                      start_Q = 0, 
                      D=1,            #Determine the Seasonal Difference as 1
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=2940.390, BIC=2946.477, Fit time=0.027 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=2910.628, BIC=2922.802, Fit time=0.135 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2847.757, BIC=2859.931, Fit time=0.481 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=2847.727, BIC=2862.944, Fit time=0.920 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 0, 12); AIC=2882.255, BIC=2894.428, Fit time=0.494 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=2843.008, BIC=2861.268, Fit time=1.992 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=2840.909, BIC=2862.213, Fit time=2.147 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=2866.173, BIC=2884.434, Fit time=2.287 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=2856.610, BIC=2880.958, Fit time=2.330 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 2, 12); AIC=2883.854, BIC=2899.071, Fit time=2.485 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=2860.694, BIC=2888.085, Fit time=2.611 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=2842.911, BIC=2861.172, Fit time=1.811 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 12); AIC=2861.635, BIC=2885.983, Fit time=2.373 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=2843.882, BIC=2862.142, Fit time=0.987 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=2844.673, BIC=2859.890, Fit time=0.953 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=2860.991, BIC=2885.338, Fit time=2.508 seconds
# Total fit time: 24.553 seconds
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(1, 1, 1)x(1, 1, 2, 12)   Log Likelihood               -1413.454
# Date:                            Fri, 22 Nov 2019   AIC                           2840.909
# Time:                                    15:33:21   BIC                           2862.213
# Sample:                                         0   HQIC                          2849.562
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    -16.9503     18.300     -0.926      0.354     -52.818      18.917
# ar.L1          0.2080      0.125      1.660      0.097      -0.038       0.453
# ma.L1         -0.7896      0.098     -8.069      0.000      -0.981      -0.598
# ar.S.L12      -0.7898      0.076    -10.379      0.000      -0.939      -0.641
# ma.S.L12       0.0835      0.220      0.380      0.704      -0.347       0.515
# ma.S.L24      -0.9089      0.078    -11.709      0.000      -1.061      -0.757
# sigma2      4.227e+06   9.99e-07   4.23e+12      0.000    4.23e+06    4.23e+06
# ===================================================================================
# Ljung-Box (Q):                       36.22   Jarque-Bera (JB):                82.74
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.85   Skew:                            -0.76
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.51e+30. Standard errors may be unstable.

# %%
model.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
n_periods = 24
train = y[:125]
test = y[125:]

fitted, confint = model.predict(n_periods=n_periods, return_conf_int=True) #Return the Confidence Interval
index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train, label ='Training')
plt.plot(test, label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast of kawasasaki Sales")
plt.show()

# %%
fitted
# Out:
# array([5169.18488766, 6869.84869125, 7619.47959288, 4992.03652424,
#        5823.09487806, 5623.65908126, 5647.13997759, 6623.23159197,
#        6292.84811784, 5178.15956779, 5424.55815819, 3785.9191356 ,
#        4796.14516339, 5777.32125561, 5073.40564809, 3680.19771568,
#        3900.04259811, 3380.45194229, 4717.01948545, 4458.43187128,
#        4379.7334079 , 4439.35663477, 3238.31421957, 3234.57272903])

# %%
confint
# Out:
# array([[ 1038.56187745,  9299.80789788],
#        [ 2390.98166362, 11348.71571888],
#        [ 2974.47516865, 12264.48401712],
#        [  212.24636903,  9771.82667945],
#        [  917.13387919, 10729.05587694],
#        [  595.67350955, 10651.64465298],
#        [  500.21210566, 10794.06784952],
#        [ 1360.0714867 , 11886.39169725],
#        [  915.94666119, 11669.7495745 ],
#        [ -310.17109944, 10666.49023503],
#        [ -173.06090755, 11022.17722393],
#        [-1919.05839899,  9490.89667018],
#        [-1319.57138938, 10911.86171616],
#        [ -534.19256737, 12088.83507859],
#        [-1397.17585781, 11543.98715399],
#        [-2939.68803447, 10300.08346583],
#        [-2864.65731686, 10664.74251309],
#        [-3525.78662754, 10286.69051212],
#        [-2327.87419829, 11761.9131692 ],
#        [-2722.45036434, 11639.31410689],
#        [-2934.65956857, 11694.12638436],
#        [-3006.32113661, 11885.03440614],
#        [-4336.9599157 , 10813.58835483],
#        [-4468.70680499, 10937.85226304]])

# %%
#Decompose the time series data to get the seasonal data. Lets try to take 36 months back in the past as exogenous variable

# multiplicative seasonal component
result_mul = sm.tsa.seasonal_decompose(y[-36:],   # 36 months
                                model='multiplicative', 
                                extrapolate_trend='freq')

# %%
plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})
fig = result_mul.plot()
plt.show()

# %%
#We would use what we called seasonal index as our exogenous varibale. We take the latest 12 month.
seasonal_index = result_mul.seasonal[-12:].to_frame()
seasonal_index['month'] = pd.to_datetime(seasonal_index.index).month

# %%
#lets merge it into one dataframe
y = pd.DataFrame(y)
y['month'] = y.index.month
df = pd.merge(y, seasonal_index, how='left', on='month')
df.columns = ['Kawasaki', 'month', 'seasonal_index']
df.index = y.index  # reassign the index.

# %%
df.head()
# Out:
#             Kawasaki  month  seasonal_index
# Periode
# 2005-01-01      7701      1        1.151963
# 2005-02-01      6821      2        1.366826
# 2005-03-01      4147      3        1.503374
# 2005-04-01      3911      4        0.707870
# 2005-05-01      5496      5        0.832230

# %%
sxmodel = pm.auto_arima(df[['Kawasaki']], exogenous=df[['seasonal_index']],
                           start_p=1, start_q=1,
                           test='adf',
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=None, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)

sxmodel.summary()
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2873.459, BIC=2891.758, Fit time=1.352 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=2962.221, BIC=2971.371, Fit time=0.016 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=2909.172, BIC=2924.421, Fit time=0.166 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2920.830, BIC=2936.079, Fit time=0.615 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=2881.215, BIC=2902.564, Fit time=1.315 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=2921.997, BIC=2937.246, Fit time=0.064 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 2, 12); AIC=2876.392, BIC=2897.741, Fit time=2.158 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=2878.322, BIC=2902.721, Fit time=2.402 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2872.697, BIC=2894.046, Fit time=1.102 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=2885.198, BIC=2903.497, Fit time=0.836 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 1, 1, 12); AIC=2881.218, BIC=2905.617, Fit time=1.344 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=2891.476, BIC=2906.725, Fit time=0.655 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 1, 1, 12); AIC=2878.489, BIC=2905.938, Fit time=1.408 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=2879.674, BIC=2904.073, Fit time=1.176 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=2922.350, BIC=2940.649, Fit time=0.111 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 2, 12); AIC=2879.642, BIC=2904.041, Fit time=2.257 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=2879.603, BIC=2907.052, Fit time=2.322 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2881.465, BIC=2905.864, Fit time=1.193 seconds
# Total fit time: 20.513 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(2, 0, 1)x(0, 1, 1, 12)   Log Likelihood               -1429.348
# Date:                            Fri, 22 Nov 2019   AIC                           2872.697
# Time:                                    15:33:44   BIC                           2894.046
# Sample:                                         0   HQIC                          2881.368
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      5.6586     14.533      0.389      0.697     -22.826      34.143
# x1             7.7799   4003.071      0.002      0.998   -7838.095    7853.655
# ar.L1          1.0540      0.130      8.087      0.000       0.799       1.309
# ar.L2         -0.0747      0.119     -0.629      0.529      -0.308       0.158
# ma.L1         -0.7400      0.102     -7.227      0.000      -0.941      -0.539
# ma.S.L12      -0.9014      0.075    -11.977      0.000      -1.049      -0.754
# sigma2      5.103e+06      4.454   1.15e+06      0.000     5.1e+06     5.1e+06
# ===================================================================================
# Ljung-Box (Q):                       48.60   Jarque-Bera (JB):                40.95
# Prob(Q):                              0.17   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.31   Skew:                            -0.51
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.71e+21. Standard errors may be unstable.
# """

# %%
train = df[:150]
test = df[150:]

fitted, confint = sxmodel.predict(n_periods=n_periods, 
                                  exogenous=np.tile(seasonal_index['Kawasaki'], 2).reshape(-1,1), 
                                  return_conf_int=True,alpha=0.05)

index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train['Kawasaki'], label ='Training')
plt.plot(test['Kawasaki'], label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMAX - Final Forecast of Motor Kawasaki Sales with Exogenous Variable")
plt.show()

# %%
fitted
# Out:
# array([5983.78306136, 7420.81209712, 7437.59419984, 5540.20357715,
#        6162.23995532, 5860.95785445, 6839.51556217, 7215.48638305,
#        7183.96783276, 6904.55581999, 6421.25435973, 5869.27076403,
#        6618.11790258, 8030.30115959, 8038.23082174, 6133.36686033,
#        6748.18813075, 6439.86002016, 7411.5306438 , 7780.76924641,
#        7742.66982494, 7456.82488288, 6967.23510916, 6409.10456478])

# %%
confint
# Out:
# array([[ 1536.54231202, 10431.02381071],
#        [ 2760.54738084, 12081.07681341],
#        [ 2641.02290573, 12234.16549395],
#        [  620.91388191, 10459.49327239],
#        [ 1128.90714528, 11195.57276536],
#        [  721.18283874, 11000.73287016],
#        [ 1600.20129693, 12078.8298274 ],
#        [ 1882.94693151, 12548.02583459],
#        [ 1764.003544  , 12603.93212151],
#        [ 1402.51499961, 12406.59664038],
#        [  842.08813341, 12000.42058605],
#        [  217.64837208, 11520.89315598],
#        [  807.12045845, 12429.11534672],
#        [ 2131.89713043, 13928.70518875],
#        [ 2061.55185319, 14014.9097903 ],
#        [   83.23934487, 12183.49437579],
#        [  628.83861026, 12867.53765124],
#        [  255.21068173, 12624.50935859],
#        [ 1165.24551697, 13657.81577064],
#        [ 1476.2790475 , 14085.25944533],
#        [ 1383.19272661, 14102.14692327],
#        [ 1045.38512459, 13868.26464116],
#        [  506.68349273, 13427.78672558],
#        [  -97.78955824, 12915.99868781]])

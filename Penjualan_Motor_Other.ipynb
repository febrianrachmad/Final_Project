# %%
#Import the usual library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import warnings
warnings.filterwarnings('ignore')

# %%
dfother = pd.read_excel('Penjualan_Motor_20052018.xlsx', index_col = 0)

# %%
dfother
# Out:
#              Honda  Yamaha  Suzuki  Kawasaki  Others   Total
# Periode
# 2005-01-01  208204   83114   83846      7701    4218  387083
# 2005-02-01  192320   78640   82381      6821    3244  363406
# 2005-03-01  217344   79752   96876      4147    2601  400720
# 2005-04-01  205691   94465  100507      3911    3170  407744
# 2005-05-01  219358  104530   87016      5496    3208  419608
# 2005-06-01  241295  120029  104493      7435    3703  476955
# 2005-07-01  238044  117049  106515      7140    3499  472247
# 2005-08-01  256591  120293  115136      9879    2888  504787
# 2005-09-01  237039  101159  102252     10152    2225  452827
# 2005-10-01  283672  108008   90829      5727    2318  490554
# 2005-11-01  188506   95897   60217      3457    1990  350067
# 2005-12-01  160126  121659   61894      2262    2247  348188
# 2006-01-01  116873  105025   39469      3153    2098  266618
# 2006-02-01  167916  123809   32600      3406    3036  330767
# 2006-03-01  145031   93331   32794      3524    1743  276423
# 2006-04-01  140214   93272   33571      2602    1433  271092
# 2006-05-01  170839  111472   37725      1297    1347  322680
# 2006-06-01  171674  122286   46724      1367    1348  343399
# 2006-07-01  186047  131615   47206      3009    2470  370347
# 2006-08-01  241416  136837   56180      3449    2406  440288
# 2006-09-01  276384  143566   67556      3644    2965  494115
# 2006-10-01  174249  109522   55616      2854    2344  344585
# 2006-11-01  293389  156679   67299      3021    3679  524067
# 2006-12-01  255136  131147   51301      2360    3017  442961
# 2007-01-01  153806  130587   52309      2940    3131  342773
# 2007-02-01  150979  145872   46123      2914    2835  348723
# 2007-03-01  151074  159035   47175      3441    3130  363855
# 2007-04-01  138434  128270   41173      3785    3263  314925
# 2007-05-01  169217  168367   32965      2665    3192  376406
# 2007-06-01  159859  154220   50391      2680    3161  370311
# ...            ...     ...     ...       ...     ...     ...
# 2016-07-01  203659   91015    3800      6584      95  305153
# 2016-08-01  388847  123972    6445      8085     187  527536
# 2016-09-01  423256  119717    4628      8036     183  555820
# 2016-10-01  446611  114493    2469      7500     128  571201
# 2016-11-01  450331  107501    4857      8104     130  570923
# 2016-12-01  309796  118078    3510      6262     118  437764
# 2017-01-01  368739   94117    3511      7370     142  473879
# 2017-02-01  345921   93511    5904      8298     129  453763
# 2017-03-01  358524   98040    8600      8601     131  473896
# 2017-04-01  274155  101908    5879      6002     101  388045
# 2017-05-01  394751  122186    8526      5915     118  531496
# 2017-06-01  263854  105133    6270      4143      67  379467
# 2017-07-01  403487  120608    7312      6690      79  538176
# 2017-08-01  418931  123620    6279      6009      84  554923
# 2017-09-01  408116  124360    6823      7224      84  546607
# 2017-10-01  436974  129636    6172      6658     112  579552
# 2017-11-01  430487  109834    3617      6274      91  550303
# 2017-12-01  281949  125258    3298      5453      38  415996
# 2018-01-01  345957  122989    6051      7509      31  482537
# 2018-02-01  339152   85429    4500     10456      49  439586
# 2018-03-01  384187  133126    4077     13969      12  535371
# 2018-04-01  458499  113182    6954      2282       4  580921
# 2018-05-01  436727  140068    7663      4828      18  589304
# 2018-06-01  271206   96150    5357      2302      19  375034
# 2018-07-01  450622  127101    8639      7366      21  593749
# 2018-08-01  443694  108896    8355      7016      95  568056
# 2018-09-01  406841  134419    9371      7036      25  557692
# 2018-10-01  456582  138012   10489      5212      27  610322
# 2018-11-01  440659  140683   10002      6003      17  597364
# 2018-12-01  325076  115033    8050      5003      19  453181
#
# [168 rows x 6 columns]

# %%
dfother.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2005-01-01 to 2018-12-01
# Data columns (total 6 columns):
# Honda       168 non-null int64
# Yamaha      168 non-null int64
# Suzuki      168 non-null int64
# Kawasaki    168 non-null int64
# Others      168 non-null int64
# Total       168 non-null int64
# dtypes: int64(6)
# memory usage: 9.2 KB

# %%
print('The data Time range from {} to {}'.format(dfother.index.min(),dfother.index.max()))
# Out:
# The data Time range from 2005-01-01 00:00:00 to 2018-12-01 00:00:00

# %%
y = dfother['Others'].resample('MS').mean()

# %%
y
# Out:
# Periode
# 2005-01-01    4218
# 2005-02-01    3244
# 2005-03-01    2601
# 2005-04-01    3170
# 2005-05-01    3208
# 2005-06-01    3703
# 2005-07-01    3499
# 2005-08-01    2888
# 2005-09-01    2225
# 2005-10-01    2318
# 2005-11-01    1990
# 2005-12-01    2247
# 2006-01-01    2098
# 2006-02-01    3036
# 2006-03-01    1743
# 2006-04-01    1433
# 2006-05-01    1347
# 2006-06-01    1348
# 2006-07-01    2470
# 2006-08-01    2406
# 2006-09-01    2965
# 2006-10-01    2344
# 2006-11-01    3679
# 2006-12-01    3017
# 2007-01-01    3131
# 2007-02-01    2835
# 2007-03-01    3130
# 2007-04-01    3263
# 2007-05-01    3192
# 2007-06-01    3161
#               ...
# 2016-07-01      95
# 2016-08-01     187
# 2016-09-01     183
# 2016-10-01     128
# 2016-11-01     130
# 2016-12-01     118
# 2017-01-01     142
# 2017-02-01     129
# 2017-03-01     131
# 2017-04-01     101
# 2017-05-01     118
# 2017-06-01      67
# 2017-07-01      79
# 2017-08-01      84
# 2017-09-01      84
# 2017-10-01     112
# 2017-11-01      91
# 2017-12-01      38
# 2018-01-01      31
# 2018-02-01      49
# 2018-03-01      12
# 2018-04-01       4
# 2018-05-01      18
# 2018-06-01      19
# 2018-07-01      21
# 2018-08-01      95
# 2018-09-01      25
# 2018-10-01      27
# 2018-11-01      17
# 2018-12-01      19
# Freq: MS, Name: Others, Length: 168, dtype: int64

# %%
y.max()
# Out:
# 4261

# %%
y.min()
# Out:
# 4

# %%
y.head()
# Out:
# Periode
# 2005-01-01    4218
# 2005-02-01    3244
# 2005-03-01    2601
# 2005-04-01    3170
# 2005-05-01    3208
# Freq: MS, Name: Others, dtype: int64

# %%
y.isna().any()
# Out:
# False

# %%
plt.figure(figsize = (18,8))
plt.title('Monthly Average of Motor others Sale')
y.plot()

# EXPONENSIAL

# %%
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='multipicative')
fig = decomposition.plot()
plt.show()

# %%
decomposition.trend
# Out:
# Periode
# 2005-01-01            NaN
# 2005-02-01            NaN
# 2005-03-01            NaN
# 2005-04-01            NaN
# 2005-05-01            NaN
# 2005-06-01            NaN
# 2005-07-01    2854.250000
# 2005-08-01    2757.250000
# 2005-09-01    2712.833333
# 2005-10-01    2604.708333
# 2005-11-01    2454.791667
# 2005-12-01    2279.125000
# 2006-01-01    2138.125000
# 2006-02-01    2075.166667
# 2006-03-01    2085.916667
# 2006-04-01    2117.833333
# 2006-05-01    2189.291667
# 2006-06-01    2291.750000
# 2006-07-01    2366.875000
# 2006-08-01    2401.541667
# 2006-09-01    2450.958333
# 2006-10-01    2585.000000
# 2006-11-01    2738.125000
# 2006-12-01    2890.541667
# 2007-01-01    3006.416667
# 2007-02-01    3095.625000
# 2007-03-01    3152.916667
# 2007-04-01    3136.875000
# 2007-05-01    3076.375000
# 2007-06-01    3054.416667
#                  ...
# 2016-07-01     158.041667
# 2016-08-01     158.750000
# 2016-09-01     155.166667
# 2016-10-01     147.500000
# 2016-11-01     138.125000
# 2016-12-01     130.750000
# 2017-01-01     126.750000
# 2017-02-01     121.791667
# 2017-03-01     113.375000
# 2017-04-01     108.583333
# 2017-05-01     106.291667
# 2017-06-01     101.333333
# 2017-07-01      93.375000
# 2017-08-01      85.416667
# 2017-09-01      77.125000
# 2017-10-01      68.125000
# 2017-11-01      59.916667
# 2017-12-01      53.750000
# 2018-01-01      49.333333
# 2018-02-01      47.375000
# 2018-03-01      45.375000
# 2018-04-01      39.375000
# 2018-05-01      32.750000
# 2018-06-01      28.875000
# 2018-07-01            NaN
# 2018-08-01            NaN
# 2018-09-01            NaN
# 2018-10-01            NaN
# 2018-11-01            NaN
# 2018-12-01            NaN
# Freq: MS, Name: Others, Length: 168, dtype: float64

# %%
#import the Augmented Dickey-Fuller Test

from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(y)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-2.249930547684453
# p-value: 0.18862487521245674

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})

# Original Series
ori = y.plot()
ori.set_title('Original Series')
plot_acf(y, title = 'Autocorellation original')

plt.show()

# %%
# 1st Differencing
diff1 = y.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_acf(y.diff().dropna(),lags =30,  title = 'Autocorellation Differenced 1')

plt.show()

# %%
# 2nd Differencing
diff2 = y.diff().diff().dropna().plot()
diff2.set_title('Time Series Differenced 2')
plot_acf(y.diff().diff().dropna(),lags = 30, title = 'Autocorellation Differenced 2')

plt.show()

# %%
# 12ve Differencing
diff12 = y.diff(12).dropna().plot()
diff12.set_title('Time Series Differenced 12')
plot_acf(y.diff(12).dropna(),lags = 30, title = 'Autocorellation Differenced 12')

plt.show()

# %%
result = adfuller(y.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-17.463328030893784
# p-value: 4.584523786654113e-30

# %%
result = adfuller(y.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-6.778835357200853
# p-value: 2.529843617899157e-09

# %%
result = adfuller(y.diff(12).dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-2.7117050048072633
# p-value: 0.07203460103902948

# %%
y_difference_1 = y.diff().dropna()

# %%
#We are using the Additive model because the plot look like it was following the addition model
decomposition_difference_1 = sm.tsa.seasonal_decompose(y_difference_1, model='additive') 
fig = decomposition_difference_1.plot()
plt.show()

# %%
y_deseason = y_difference_1/ decomposition_difference_1.seasonal

# %%
#Deseason original
ori_deseason = y_deseason.plot()
ori_deseason.set_title('Deseason Original')
plot_acf(y_deseason, title = 'Deseason original Autocorellation')

plt.show()

# %%
result = adfuller(y_deseason)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-12.781066682122338
# p-value: 7.413730051071288e-24

# %%
# 1st Differencing
diff1_deseason = y_deseason.diff().dropna().plot()
diff1_deseason.set_title('Time Series Deseason Differenced 1')
plot_acf(y_deseason.diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 1')

plt.show()

# %%
result = adfuller(y_deseason.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-7.028987340810444
# p-value: 6.256314806295628e-10

# %%
# 2nd Differencing
diff2_deseason = y_deseason.diff().diff().dropna().plot()
diff2_deseason.set_title('Time Series Deseason Differenced 2')
plot_acf(y_deseason.diff().diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 2')

plt.show()

# %%
result = adfuller(y_deseason.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-7.087373904784969
# p-value: 4.501881817406691e-10

# %%
#PACF
diff1 = y_deseason.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_pacf(y_deseason.diff().dropna(), lags = 30, title = 'Partial Autocorellation Differenced 1')

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(y_deseason,order =(1,1,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D.Others   No. Observations:                  166
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -945.816
# Method:                       css-mle   S.D. of innovations             71.050
# Date:                Fri, 22 Nov 2019   AIC                           1899.633
# Time:                        15:29:29   BIC                           1912.081
# Sample:                    03-01-2005   HQIC                          1904.686
#                          - 12-01-2018
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0744      0.115     -0.648      0.518      -0.299       0.151
# ar.L1.D.Others     0.0069      0.078      0.089      0.929      -0.146       0.159
# ma.L1.D.Others    -1.0000      0.024    -42.282      0.000      -1.046      -0.954
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          144.9147           +0.0000j          144.9147            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
plt.rcParams.update({'figure.figsize':(12,3), 'figure.dpi':120})
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
#Data split by close to 1:4 ratio

train = y_deseason[:125]
test = y_deseason[125:]

# %%
n_periods = 24
model = ARIMA(train, order=(1, 1, 1))  
fitted = model.fit(disp=-1)  

# Forecast (resulted in forecast, standard error, and confidence interval)
fc, se, conf = fitted.forecast(42, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    
    mins = np.amin(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
  
    return({'mape':mape,'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test)
# Out:
# {'mape': inf, 'corr': -0.06461021569512707, 'minmax': inf}

# %%
import pmdarima as pm

model = pm.auto_arima(y_deseason, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series (1 as monthly)
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# Fit ARIMA: order=(1, 0, 1); AIC=1905.311, BIC=1917.783, Fit time=0.078 seconds
# Fit ARIMA: order=(0, 0, 0); AIC=1901.313, BIC=1907.549, Fit time=0.002 seconds
# Fit ARIMA: order=(1, 0, 0); AIC=1903.311, BIC=1912.665, Fit time=0.011 seconds
# Fit ARIMA: order=(0, 0, 1); AIC=1903.311, BIC=1912.665, Fit time=0.018 seconds
# Total fit time: 0.112 seconds
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  167
# Model:                     ARMA(0, 0)   Log Likelihood                -948.657
# Method:                           css   S.D. of innovations             70.926
# Date:                Fri, 22 Nov 2019   AIC                           1901.313
# Time:                        15:29:31   BIC                           1907.549
# Sample:                             0   HQIC                          1903.844
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0507      5.488     -0.009      0.993     -10.808      10.706
# ==============================================================================
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
model.plot_diagnostics(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(y, label='Original Series')
axes[0].plot(y.diff(), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)

# Seasonal Differencing
axes[1].plot(y, label='Original Series')
axes[1].plot(y.diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('Motor Others Sales', fontsize=16)
plt.show()

# %%
model = pm.auto_arima(y, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=5, max_q=5, # maximum p and q
                      m=12,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # with Seasonality
                      start_P=0, 
                      start_Q = 0, 
                      D=1,            #Determine the Seasonal Difference as 1
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=2652.153, BIC=2658.253, Fit time=0.021 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=2450.359, BIC=2462.559, Fit time=0.582 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2486.464, BIC=2498.663, Fit time=0.688 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=2484.069, BIC=2493.218, Fit time=0.181 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=2438.358, BIC=2453.607, Fit time=1.798 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=2419.640, BIC=2437.939, Fit time=2.194 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=2562.807, BIC=2578.056, Fit time=1.907 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=2413.823, BIC=2435.172, Fit time=2.433 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 1, 1, 12); AIC=2414.881, BIC=2439.279, Fit time=2.310 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 1, 1, 12); AIC=2418.356, BIC=2445.805, Fit time=2.705 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=2411.978, BIC=2430.278, Fit time=0.983 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=2444.415, BIC=2459.665, Fit time=0.429 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 2, 12); AIC=2414.320, BIC=2435.669, Fit time=2.570 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=2481.987, BIC=2494.186, Fit time=0.187 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 2, 12); AIC=2413.269, BIC=2437.667, Fit time=2.611 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=2415.267, BIC=2430.516, Fit time=0.918 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=2411.995, BIC=2433.344, Fit time=1.049 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=2412.439, BIC=2433.788, Fit time=1.076 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=2413.994, BIC=2438.393, Fit time=1.340 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=2410.368, BIC=2425.618, Fit time=0.574 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 2, 12); AIC=2411.982, BIC=2430.281, Fit time=1.426 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=2413.935, BIC=2426.135, Fit time=0.441 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=2410.884, BIC=2429.184, Fit time=0.436 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2411.332, BIC=2429.631, Fit time=0.935 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2412.800, BIC=2434.149, Fit time=1.083 seconds
# Total fit time: 30.889 seconds
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(2, 0, 0)x(0, 1, 1, 12)   Log Likelihood               -1200.184
# Date:                            Fri, 22 Nov 2019   AIC                           2410.368
# Time:                                    15:30:03   BIC                           2425.618
# Sample:                                         0   HQIC                          2416.562
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    -29.8871     12.647     -2.363      0.018     -54.674      -5.100
# ar.L1          0.6293      0.063      9.998      0.000       0.506       0.753
# ar.L2          0.1924      0.052      3.686      0.000       0.090       0.295
# ma.S.L12      -0.9852      1.095     -0.900      0.368      -3.130       1.160
# sigma2      2.288e+05   2.44e+05      0.936      0.349    -2.5e+05    7.08e+05
# ===================================================================================
# Ljung-Box (Q):                       65.81   Jarque-Bera (JB):                 9.28
# Prob(Q):                              0.01   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.09   Skew:                             0.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
n_periods = 24
train = y[:125]
test = y[125:]

fitted, confint = model.predict(n_periods=n_periods, return_conf_int=True) #Return the Confidence Interval
index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train, label ='Training')
plt.plot(test, label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast of others Sales")
plt.show()

# %%
fitted
# Out:
# array([ 302.15483672,  191.98810455,   66.33191538,  158.11785648,
#          62.27022765,  143.01541552,  145.68586291,  -43.4042613 ,
#         -11.75114305, -224.98558329, -231.19369383, -379.63667328,
#         -26.34547436, -121.31444392, -223.91449534, -114.69537888,
#        -195.13676796, -101.3425985 ,  -87.4965485 , -267.04347867,
#        -227.2348457 , -433.50108344, -433.75513136, -577.11066372])

# %%
confint
# Out:
# array([[ -661.98185326,  1266.2915267 ],
#        [ -946.36170869,  1330.33791779],
#        [-1204.73935124,  1337.403182  ],
#        [-1197.72079022,  1513.95650318],
#        [-1352.8781718 ,  1477.4186271 ],
#        [-1313.7116151 ,  1599.74244614],
#        [-1340.62041092,  1631.99213674],
#        [-1550.85505682,  1464.04653422],
#        [-1534.34937728,  1510.84709118],
#        [-1758.39991075,  1308.42874417],
#        [-1772.21789627,  1309.83050862],
#        [-1925.88711236,  1166.61376579],
#        [-1581.59293371,  1528.901985  ],
#        [-1682.41168702,  1439.78279919],
#        [-1789.50683501,  1341.67784433],
#        [-1683.5010932 ,  1454.11033543],
#        [-1766.26763279,  1375.99409688],
#        [-1674.13313763,  1471.44794064],
#        [-1661.45258888,  1486.45949188],
#        [-1841.78767479,  1307.70071745],
#        [-1802.46563554,  1347.99594413],
#        [-2008.95823015,  1141.95606326],
#        [-2009.16041651,  1141.65015378],
#        [-2152.20879807,   997.98747064]])

# %%
#Decompose the time series data to get the seasonal data. Lets try to take 36 months back in the past as exogenous variable

# multiplicative seasonal component
result_mul = sm.tsa.seasonal_decompose(y[-36:],   # 36 months
                                model='multiplicative', 
                                extrapolate_trend='freq')

# %%
plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})
fig = result_mul.plot()
plt.show()

# %%
#We would use what we called seasonal index as our exogenous varibale. We take the latest 12 month.
seasonal_index = result_mul.seasonal[-12:].to_frame()
seasonal_index['month'] = pd.to_datetime(seasonal_index.index).month

# %%
#lets merge it into one dataframe
y = pd.DataFrame(y)
y['month'] = y.index.month
df = pd.merge(y, seasonal_index, how='left', on='month')
df.columns = ['Others', 'month', 'seasonal_index']
df.index = y.index  # reassign the index.

# %%
df.head()
# Out:
#             Others  month  seasonal_index
# Periode
# 2005-01-01    4218      1        5.544299
# 2005-02-01    3244      2        7.269726
# 2005-03-01    2601      3        6.036197
# 2005-04-01    3170      4        5.733739
# 2005-05-01    3208      5        7.198781

# %%
sxmodel = pm.auto_arima(df[['Others']], exogenous=df[['seasonal_index']],
                           start_p=1, start_q=1,
                           test='adf',
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=None, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)

sxmodel.summary()
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2412.316, BIC=2430.615, Fit time=1.002 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=2654.153, BIC=2663.303, Fit time=0.029 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=2452.091, BIC=2467.340, Fit time=0.854 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2488.462, BIC=2503.711, Fit time=0.978 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=2414.086, BIC=2435.435, Fit time=1.268 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=2468.753, BIC=2484.002, Fit time=0.428 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 2, 12); AIC=2414.091, BIC=2435.440, Fit time=2.298 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=2413.544, BIC=2437.942, Fit time=3.923 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=2412.383, BIC=2433.732, Fit time=1.166 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=2415.188, BIC=2430.437, Fit time=0.722 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 1, 1, 12); AIC=2412.354, BIC=2433.703, Fit time=1.199 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=2560.680, BIC=2572.879, Fit time=0.378 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 1, 1, 12); AIC=2417.504, BIC=2441.903, Fit time=1.374 seconds
# Total fit time: 15.627 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 12)   Log Likelihood               -1200.158
# Date:                            Fri, 22 Nov 2019   AIC                           2412.316
# Time:                                    15:30:22   BIC                           2430.615
# Sample:                                         0   HQIC                          2419.748
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    -21.8133      9.422     -2.315      0.021     -40.280      -3.346
# x1           -43.4984     25.093     -1.734      0.083     -92.679       5.682
# ar.L1          0.8651      0.039     22.004      0.000       0.788       0.942
# ma.L1         -0.1998      0.066     -3.035      0.002      -0.329      -0.071
# ma.S.L12      -0.9988      0.095    -10.487      0.000      -1.185      -0.812
# sigma2      2.252e+05   9.63e-06   2.34e+10      0.000    2.25e+05    2.25e+05
# ===================================================================================
# Ljung-Box (Q):                       60.70   Jarque-Bera (JB):                 6.79
# Prob(Q):                              0.02   Prob(JB):                         0.03
# Heteroskedasticity (H):               0.09   Skew:                             0.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.11e+29. Standard errors may be unstable.
# """

# %%
train = df[:150]
test = df[150:]

fitted, confint = sxmodel.predict(n_periods=n_periods, 
                                  exogenous=np.tile(seasonal_index['Others'], 2).reshape(-1,1), 
                                  return_conf_int=True,alpha=0.05)

index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train['Others'], label ='Training')
plt.plot(test['Others'], label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMAX - Final Forecast of Motor Others Sales with Exogenous Variable")
plt.show()

# %%
fitted
# Out:
# array([ 304.24983642,  188.98007527,   70.23420343,  165.52770515,
#          72.43714094,  157.07744004,  162.72672996,  -27.67251687,
#          18.40852132, -161.2704522 , -191.58306523, -342.39009332,
#           3.69541947,  -92.84641295, -195.39053199,  -86.08070217,
#        -167.04557506,  -71.91519688,  -57.1908154 , -239.73909312,
#        -186.86608863, -360.66925172, -385.8986316 , -532.30809453])

# %%
confint
# Out:
# array([[ -658.33137477,  1266.83104762],
#        [ -966.24419784,  1344.20434839],
#        [-1210.17017618,  1350.63858305],
#        [-1200.96551312,  1532.02092343],
#        [-1355.00786823,  1499.88215011],
#        [-1314.26018038,  1628.41506046],
#        [-1340.54768027,  1666.0011402 ],
#        [-1554.32436911,  1498.97933536],
#        [-1525.39526755,  1562.21231019],
#        [-1717.63237767,  1395.09147326],
#        [-1757.05060298,  1373.88447253],
#        [-1914.28099431,  1229.50080767],
#        [-1578.59655138,  1585.98739032],
#        [-1682.25203232,  1496.55920642],
#        [-1790.0985725 ,  1399.31750851],
#        [-1684.72570533,  1512.56430098],
#        [-1768.60074549,  1434.50959536],
#        [-1675.60587596,  1531.77548219],
#        [-1662.42704707,  1548.04541626],
#        [-1846.06314129,  1366.58495504],
#        [-1793.91013722,  1420.17795997],
#        [-1968.11783641,  1246.77933297],
#        [-1993.44806094,  1221.65079775],
#        [-2139.60873918,  1074.99255012]])

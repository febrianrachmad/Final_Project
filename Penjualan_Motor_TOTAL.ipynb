# %%
#Import the usual library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import warnings
warnings.filterwarnings('ignore')

# %%
dftotal = pd.read_excel('Penjualan_Motor_20052018.xlsx', index_col = 0)

# %%
dftotal
# Out:
#              Honda  Yamaha  Suzuki  Kawasaki  Others   Total
# Periode
# 2005-01-01  208204   83114   83846      7701    4218  387083
# 2005-02-01  192320   78640   82381      6821    3244  363406
# 2005-03-01  217344   79752   96876      4147    2601  400720
# 2005-04-01  205691   94465  100507      3911    3170  407744
# 2005-05-01  219358  104530   87016      5496    3208  419608
# 2005-06-01  241295  120029  104493      7435    3703  476955
# 2005-07-01  238044  117049  106515      7140    3499  472247
# 2005-08-01  256591  120293  115136      9879    2888  504787
# 2005-09-01  237039  101159  102252     10152    2225  452827
# 2005-10-01  283672  108008   90829      5727    2318  490554
# 2005-11-01  188506   95897   60217      3457    1990  350067
# 2005-12-01  160126  121659   61894      2262    2247  348188
# 2006-01-01  116873  105025   39469      3153    2098  266618
# 2006-02-01  167916  123809   32600      3406    3036  330767
# 2006-03-01  145031   93331   32794      3524    1743  276423
# 2006-04-01  140214   93272   33571      2602    1433  271092
# 2006-05-01  170839  111472   37725      1297    1347  322680
# 2006-06-01  171674  122286   46724      1367    1348  343399
# 2006-07-01  186047  131615   47206      3009    2470  370347
# 2006-08-01  241416  136837   56180      3449    2406  440288
# 2006-09-01  276384  143566   67556      3644    2965  494115
# 2006-10-01  174249  109522   55616      2854    2344  344585
# 2006-11-01  293389  156679   67299      3021    3679  524067
# 2006-12-01  255136  131147   51301      2360    3017  442961
# 2007-01-01  153806  130587   52309      2940    3131  342773
# 2007-02-01  150979  145872   46123      2914    2835  348723
# 2007-03-01  151074  159035   47175      3441    3130  363855
# 2007-04-01  138434  128270   41173      3785    3263  314925
# 2007-05-01  169217  168367   32965      2665    3192  376406
# 2007-06-01  159859  154220   50391      2680    3161  370311
# ...            ...     ...     ...       ...     ...     ...
# 2016-07-01  203659   91015    3800      6584      95  305153
# 2016-08-01  388847  123972    6445      8085     187  527536
# 2016-09-01  423256  119717    4628      8036     183  555820
# 2016-10-01  446611  114493    2469      7500     128  571201
# 2016-11-01  450331  107501    4857      8104     130  570923
# 2016-12-01  309796  118078    3510      6262     118  437764
# 2017-01-01  368739   94117    3511      7370     142  473879
# 2017-02-01  345921   93511    5904      8298     129  453763
# 2017-03-01  358524   98040    8600      8601     131  473896
# 2017-04-01  274155  101908    5879      6002     101  388045
# 2017-05-01  394751  122186    8526      5915     118  531496
# 2017-06-01  263854  105133    6270      4143      67  379467
# 2017-07-01  403487  120608    7312      6690      79  538176
# 2017-08-01  418931  123620    6279      6009      84  554923
# 2017-09-01  408116  124360    6823      7224      84  546607
# 2017-10-01  436974  129636    6172      6658     112  579552
# 2017-11-01  430487  109834    3617      6274      91  550303
# 2017-12-01  281949  125258    3298      5453      38  415996
# 2018-01-01  345957  122989    6051      7509      31  482537
# 2018-02-01  339152   85429    4500     10456      49  439586
# 2018-03-01  384187  133126    4077     13969      12  535371
# 2018-04-01  458499  113182    6954      2282       4  580921
# 2018-05-01  436727  140068    7663      4828      18  589304
# 2018-06-01  271206   96150    5357      2302      19  375034
# 2018-07-01  450622  127101    8639      7366      21  593749
# 2018-08-01  443694  108896    8355      7016      95  568056
# 2018-09-01  406841  134419    9371      7036      25  557692
# 2018-10-01  456582  138012   10489      5212      27  610322
# 2018-11-01  440659  140683   10002      6003      17  597364
# 2018-12-01  325076  115033    8050      5003      19  453181
#
# [168 rows x 6 columns]

# %%
dftotal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2005-01-01 to 2018-12-01
# Data columns (total 6 columns):
# Honda       168 non-null int64
# Yamaha      168 non-null int64
# Suzuki      168 non-null int64
# Kawasaki    168 non-null int64
# Others      168 non-null int64
# Total       168 non-null int64
# dtypes: int64(6)
# memory usage: 9.2 KB

# %%
print('The data Time range from {} to {}'.format(dftotal.index.min(),dftotal.index.max()))
# Out:
# The data Time range from 2005-01-01 00:00:00 to 2018-12-01 00:00:00

# %%
y = dftotal['Total'].resample('MS').mean()

# %%
y
# Out:
# Periode
# 2005-01-01    387083
# 2005-02-01    363406
# 2005-03-01    400720
# 2005-04-01    407744
# 2005-05-01    419608
# 2005-06-01    476955
# 2005-07-01    472247
# 2005-08-01    504787
# 2005-09-01    452827
# 2005-10-01    490554
# 2005-11-01    350067
# 2005-12-01    348188
# 2006-01-01    266618
# 2006-02-01    330767
# 2006-03-01    276423
# 2006-04-01    271092
# 2006-05-01    322680
# 2006-06-01    343399
# 2006-07-01    370347
# 2006-08-01    440288
# 2006-09-01    494115
# 2006-10-01    344585
# 2006-11-01    524067
# 2006-12-01    442961
# 2007-01-01    342773
# 2007-02-01    348723
# 2007-03-01    363855
# 2007-04-01    314925
# 2007-05-01    376406
# 2007-06-01    370311
#                ...
# 2016-07-01    305153
# 2016-08-01    527536
# 2016-09-01    555820
# 2016-10-01    571201
# 2016-11-01    570923
# 2016-12-01    437764
# 2017-01-01    473879
# 2017-02-01    453763
# 2017-03-01    473896
# 2017-04-01    388045
# 2017-05-01    531496
# 2017-06-01    379467
# 2017-07-01    538176
# 2017-08-01    554923
# 2017-09-01    546607
# 2017-10-01    579552
# 2017-11-01    550303
# 2017-12-01    415996
# 2018-01-01    482537
# 2018-02-01    439586
# 2018-03-01    535371
# 2018-04-01    580921
# 2018-05-01    589304
# 2018-06-01    375034
# 2018-07-01    593749
# 2018-08-01    568056
# 2018-09-01    557692
# 2018-10-01    610322
# 2018-11-01    597364
# 2018-12-01    453181
# Freq: MS, Name: Total, Length: 168, dtype: int64

# %%
y.max()
# Out:
# 750829

# %%
y.min()
# Out:
# 266618

# %%
y.head()
# Out:
# Periode
# 2005-01-01    387083
# 2005-02-01    363406
# 2005-03-01    400720
# 2005-04-01    407744
# 2005-05-01    419608
# Freq: MS, Name: Total, dtype: int64

# %%
y.isna().any()
# Out:
# False

# %%
plt.figure(figsize = (18,8))
plt.title('Monthly Average of Motor total Sale')
y.plot()

# EXPONENSIAL

# %%
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='multipicative')
fig = decomposition.plot()
plt.show()

# %%
decomposition.trend
# Out:
# Periode
# 2005-01-01              NaN
# 2005-02-01              NaN
# 2005-03-01              NaN
# 2005-04-01              NaN
# 2005-05-01              NaN
# 2005-06-01              NaN
# 2005-07-01    417829.458333
# 2005-08-01    411450.125000
# 2005-09-01    404911.125000
# 2005-10-01    394038.250000
# 2005-11-01    384305.750000
# 2005-12-01    374702.250000
# 2006-01-01    364891.583333
# 2006-02-01    357958.291667
# 2006-03-01    356991.166667
# 2006-04-01    352629.458333
# 2006-05-01    353797.416667
# 2006-06-01    364996.291667
# 2006-07-01    372118.291667
# 2006-08-01    376039.583333
# 2006-09-01    380430.750000
# 2006-10-01    385900.125000
# 2006-11-01    389965.083333
# 2006-12-01    393325.000000
# 2007-01-01    394198.000000
# 2007-02-01    393401.958333
# 2007-03-01    392144.125000
# 2007-04-01    394675.875000
# 2007-05-01    396372.333333
# 2007-06-01    392757.750000
#                   ...
# 2016-07-01    496674.416667
# 2016-08-01    496112.541667
# 2016-09-01    489423.125000
# 2016-10-01    481946.625000
# 2016-11-01    481113.250000
# 2016-12-01    478220.708333
# 2017-01-01    482121.208333
# 2017-02-01    492971.625000
# 2017-03-01    493728.875000
# 2017-04-01    493692.958333
# 2017-05-01    493181.750000
# 2017-06-01    491415.583333
# 2017-07-01    490869.333333
# 2017-08-01    490639.375000
# 2017-09-01    492610.125000
# 2017-10-01    503208.083333
# 2017-11-01    513653.250000
# 2017-12-01    515877.208333
# 2018-01-01    518008.041667
# 2018-02-01    520870.791667
# 2018-03-01    521879.875000
# 2018-04-01    523623.833333
# 2018-05-01    526866.791667
# 2018-06-01    530377.041667
# 2018-07-01              NaN
# 2018-08-01              NaN
# 2018-09-01              NaN
# 2018-10-01              NaN
# 2018-11-01              NaN
# 2018-12-01              NaN
# Freq: MS, Name: Total, Length: 168, dtype: float64

# %%
#import the Augmented Dickey-Fuller Test

from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(y)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-2.0266855444101632
# p-value: 0.2749963589471651

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})

# Original Series
ori = y.plot()
ori.set_title('Original Series')
plot_acf(y, title = 'Autocorellation original')

plt.show()

# %%
# 1st Differencing
diff1 = y.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_acf(y.diff().dropna(),lags =30,  title = 'Autocorellation Differenced 1')

plt.show()

# %%
# 2nd Differencing
diff2 = y.diff().diff().dropna().plot()
diff2.set_title('Time Series Differenced 2')
plot_acf(y.diff().diff().dropna(),lags = 30, title = 'Autocorellation Differenced 2')

plt.show()

# %%
# 12ve Differencing
diff12 = y.diff(12).dropna().plot()
diff12.set_title('Time Series Differenced 12')
plot_acf(y.diff(12).dropna(),lags = 30, title = 'Autocorellation Differenced 12')

plt.show()

# %%
result = adfuller(y.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-4.018618054846295
# p-value: 0.0013160987804473356

# %%
result = adfuller(y.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-7.632435253120779
# p-value: 1.992412151122016e-11

# %%
result = adfuller(y.diff(12).dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-3.8686569575015075
# p-value: 0.002278013721426694

# %%
y_difference_2 = y.diff().diff().dropna()

# %%
#We are using the Additive model because the plot look like it was following the addition model
decomposition_difference_2 = sm.tsa.seasonal_decompose(y_difference_2, model='additive') 
fig = decomposition_difference_2.plot()
plt.show()

# %%
y_deseason = y_difference_2/ decomposition_difference_2.seasonal

# %%
#Deseason original
ori_deseason = y_deseason.plot()
ori_deseason.set_title('Deseason Original')
plot_acf(y_deseason, title = 'Deseason original Autocorellation')

plt.show()

# %%
result = adfuller(y_deseason)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-2.744899679450391
# p-value: 0.06658567124148053

# %%
# 1st Differencing
diff1_deseason = y_deseason.diff().dropna().plot()
diff1_deseason.set_title('Time Series Deseason Differenced 1')
plot_acf(y_deseason.diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 1')

plt.show()

# %%
result = adfuller(y_deseason.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-5.955146061804098
# p-value: 2.1018558724714334e-07

# %%
# 2nd Differencing
diff2_deseason = y_deseason.diff().diff().dropna().plot()
diff2_deseason.set_title('Time Series Deseason Differenced 2')
plot_acf(y_deseason.diff().diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 2')

plt.show()

# %%
result = adfuller(y_deseason.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-7.95600704626615
# p-value: 3.0361189873483925e-12

# %%
#PACF
diff1 = y_deseason.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_pacf(y_deseason.diff().dropna(), lags = 30, title = 'Partial Autocorellation Differenced 1')

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(y_deseason,order =(1,1,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Total   No. Observations:                  165
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -740.661
# Method:                       css-mle   S.D. of innovations             21.193
# Date:                Fri, 22 Nov 2019   AIC                           1489.323
# Time:                        03:39:40   BIC                           1501.747
# Sample:                    04-01-2005   HQIC                          1494.366
#                          - 12-01-2018
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0192      0.031     -0.627      0.532      -0.079       0.041
# ar.L1.D.Total    -0.1216      0.077     -1.574      0.117      -0.273       0.030
# ma.L1.D.Total    -1.0000      0.031    -31.789      0.000      -1.062      -0.938
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -8.2208           +0.0000j            8.2208            0.5000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
plt.rcParams.update({'figure.figsize':(12,3), 'figure.dpi':120})
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
#Data split by close to 1:4 ratio

train = y_deseason[:125]
test = y_deseason[125:]

# %%
n_periods = 24
model = ARIMA(train, order=(1, 1, 1))  
fitted = model.fit(disp=-1)  

# Forecast (resulted in forecast, standard error, and confidence interval)
fc, se, conf = fitted.forecast(41, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    
    mins = np.amin(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
  
    return({'mape':mape,'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test)
# Out:
# {'mape': 2.16880604517634,
#  'corr': 0.10116363388772362,
#  'minmax': -0.15388198692667743}

# %%
import pmdarima as pm

model = pm.auto_arima(y_deseason, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series (1 as monthly)
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# Fit ARIMA: order=(1, 0, 1); AIC=1492.279, BIC=1504.727, Fit time=0.043 seconds
# Fit ARIMA: order=(0, 0, 0); AIC=1490.943, BIC=1497.167, Fit time=0.001 seconds
# Fit ARIMA: order=(1, 0, 0); AIC=1490.317, BIC=1499.653, Fit time=0.014 seconds
# Fit ARIMA: order=(0, 0, 1); AIC=1490.279, BIC=1499.615, Fit time=0.016 seconds
# Fit ARIMA: order=(0, 0, 2); AIC=1492.279, BIC=1504.727, Fit time=0.025 seconds
# Fit ARIMA: order=(1, 0, 2); AIC=1494.277, BIC=1509.837, Fit time=0.107 seconds
# Total fit time: 0.208 seconds
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  166
# Model:                     ARMA(0, 1)   Log Likelihood                -742.139
# Method:                       css-mle   S.D. of innovations             21.152
# Date:                Fri, 22 Nov 2019   AIC                           1490.279
# Time:                        03:39:42   BIC                           1499.615
# Sample:                             0   HQIC                          1494.068
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6073      1.434      0.423      0.672      -2.204       3.418
# ma.L1.y       -0.1272      0.077     -1.648      0.101      -0.279       0.024
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            7.8606           +0.0000j            7.8606            0.0000
# -----------------------------------------------------------------------------

# %%
model.plot_diagnostics(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(y, label='Original Series')
axes[0].plot(y.diff(), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)

# Seasonal Differencing
axes[1].plot(y, label='Original Series')
axes[1].plot(y.diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('Motor Total Sales', fontsize=16)
plt.show()

# %%
model = pm.auto_arima(y, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=5, max_q=5, # maximum p and q
                      m=12,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # with Seasonality
                      start_P=0, 
                      start_Q = 0, 
                      D=1,            #Determine the Seasonal Difference as 1
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=4043.936, BIC=4050.036, Fit time=0.017 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=3993.267, BIC=4005.466, Fit time=0.226 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=4013.915, BIC=4026.114, Fit time=0.130 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=3997.922, BIC=4007.072, Fit time=0.034 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=3991.584, BIC=4006.833, Fit time=0.276 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=3992.296, BIC=4010.596, Fit time=0.928 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=4037.555, BIC=4049.755, Fit time=0.194 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=3973.013, BIC=3991.312, Fit time=0.482 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 1, 0, 12); AIC=3974.380, BIC=3995.729, Fit time=0.831 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 1, 0, 12); AIC=3976.203, BIC=4000.602, Fit time=0.931 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=3975.831, BIC=3991.081, Fit time=0.208 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=3973.794, BIC=3995.143, Fit time=1.136 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=3974.214, BIC=3995.563, Fit time=0.460 seconds
# Total fit time: 5.858 seconds
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(2, 0, 0)x(2, 1, 0, 12)   Log Likelihood               -1980.507
# Date:                            Fri, 22 Nov 2019   AIC                           3973.013
# Time:                                    03:39:49   BIC                           3991.312
# Sample:                                         0   HQIC                          3980.446
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3313.2836   6884.461      0.481      0.630   -1.02e+04    1.68e+04
# ar.L1          0.2983      0.061      4.870      0.000       0.178       0.418
# ar.L2          0.3436      0.066      5.174      0.000       0.213       0.474
# ar.S.L12      -0.2678      0.066     -4.048      0.000      -0.397      -0.138
# ar.S.L24      -0.1625      0.071     -2.276      0.023      -0.302      -0.023
# sigma2      6.016e+09      0.006   1.07e+12      0.000    6.02e+09    6.02e+09
# ===================================================================================
# Ljung-Box (Q):                       70.83   Jarque-Bera (JB):                 8.40
# Prob(Q):                              0.00   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.88   Skew:                            -0.12
# Prob(H) (two-sided):                  0.64   Kurtosis:                         4.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.76e+27. Standard errors may be unstable.

# %%
model.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
n_periods = 24
train = y[:125]
test = y[125:]

fitted, confint = model.predict(n_periods=n_periods, return_conf_int=True) #Return the Confidence Interval
index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train, label ='Training')
plt.plot(test, label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast of total Sales")
plt.show()

# %%
fitted
# Out:
# array([495756.69023924, 471838.68588081, 550357.81072665, 558066.16982018,
#        575800.25300886, 411040.65756851, 552526.95318032, 571020.24620319,
#        566756.69990774, 610938.02177627, 598093.62284932, 456561.1982277 ,
#        500475.49394223, 475070.30641272, 545841.54791367, 542269.88986196,
#        579407.46176352, 411473.11565548, 563861.82886952, 577402.14980952,
#        571823.88995689, 615057.72029539, 599527.34363485, 458884.17760686])

# %%
confint
# Out:
# array([[343734.95580139, 647778.4246771 ],
#        [313196.15717156, 630481.21459006],
#        [378624.96671119, 722090.65474212],
#        [382762.70222138, 733369.63741899],
#        [397399.86277485, 754200.64324287],
#        [231292.7481086 , 590788.56702842],
#        [371887.44689519, 733166.45946546],
#        [389921.01675096, 752119.47565543],
#        [385381.25261257, 748132.14720291],
#        [429411.03058552, 792465.01296703],
#        [416478.71468964, 779708.531009  ],
#        [274896.95082365, 638225.44563174],
#        [285727.40946017, 715223.57842429],
#        [257388.26658832, 692752.34623711],
#        [322496.85394441, 769186.24188293],
#        [317281.4286127 , 767258.35111121],
#        [353004.43108352, 805810.49244352],
#        [184442.74849019, 638503.48282077],
#        [336417.65522875, 791306.00251029],
#        [349743.22508898, 805061.07453006],
#        [344036.0965857 , 799611.68332807],
#        [387199.06512694, 842916.37546383],
#        [371627.59934078, 827427.08792892],
#        [230961.35574652, 686806.99946721]])

# %%
#Decompose the time series data to get the seasonal data. Lets try to take 36 months back in the past as exogenous variable

# multiplicative seasonal component
result_mul = sm.tsa.seasonal_decompose(y[-36:],   # 36 months
                                model='multiplicative', 
                                extrapolate_trend='freq')

# %%
plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})
fig = result_mul.plot()
plt.show()

# %%
#We would use what we called seasonal index as our exogenous varibale. We take the latest 12 month.
seasonal_index = result_mul.seasonal[-12:].to_frame()
seasonal_index['month'] = pd.to_datetime(seasonal_index.index).month

# %%
#lets merge it into one dataframe
y = pd.DataFrame(y)
y['month'] = y.index.month
df = pd.merge(y, seasonal_index, how='left', on='month')
df.columns = ['Total', 'month', 'seasonal_index']
df.index = y.index  # reassign the index.

# %%
df.head()
# Out:
#              Total  month  seasonal_index
# Periode
# 2005-01-01  387083      1        0.923900
# 2005-02-01  363406      2        0.948074
# 2005-03-01  400720      3        1.048133
# 2005-04-01  407744      4        0.959542
# 2005-05-01  419608      5        1.048511

# %%
sxmodel = pm.auto_arima(df[['Total']], exogenous=df[['seasonal_index']],
                           start_p=1, start_q=1,
                           test='adf',
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=None, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)

sxmodel.summary()
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=3979.424, BIC=3997.723, Fit time=0.317 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=4045.936, BIC=4055.085, Fit time=0.014 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=3995.267, BIC=4010.516, Fit time=0.152 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=4015.915, BIC=4031.164, Fit time=0.132 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3971.254, BIC=3992.603, Fit time=0.504 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 0, 12); AIC=3984.049, BIC=4002.348, Fit time=0.231 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=3970.639, BIC=3995.038, Fit time=0.887 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=4016.668, BIC=4038.017, Fit time=0.928 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=3968.264, BIC=3995.712, Fit time=1.853 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 2, 12); AIC=3966.703, BIC=3991.102, Fit time=1.270 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=3970.029, BIC=4000.528, Fit time=2.337 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 2, 12); AIC=3967.206, BIC=3988.555, Fit time=0.904 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 2, 12); AIC=3968.671, BIC=3996.120, Fit time=2.342 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=3964.712, BIC=3986.061, Fit time=0.623 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=3987.086, BIC=4002.335, Fit time=0.081 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=3983.711, BIC=4002.011, Fit time=0.446 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=3966.129, BIC=3990.527, Fit time=0.552 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3966.451, BIC=3990.850, Fit time=0.588 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3968.051, BIC=3995.500, Fit time=0.839 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=3974.322, BIC=3992.621, Fit time=0.253 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=3975.794, BIC=4000.193, Fit time=1.308 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=3977.831, BIC=3996.130, Fit time=0.322 seconds
# Total fit time: 16.897 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 12)   Log Likelihood               -1975.356
# Date:                            Fri, 22 Nov 2019   AIC                           3964.712
# Time:                                    03:40:09   BIC                           3986.061
# Sample:                                         0   HQIC                          3973.383
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3313.2836   1600.268      2.070      0.038     176.816    6449.751
# x1             0.0001   5.17e+04   1.97e-09      1.000   -1.01e+05    1.01e+05
# ar.L1          0.3960      0.091      4.347      0.000       0.217       0.575
# ar.L2          0.3453      0.084      4.100      0.000       0.180       0.510
# ar.S.L12       0.4745      0.114      4.176      0.000       0.252       0.697
# ma.S.L12      -0.9532      0.174     -5.488      0.000      -1.294      -0.613
# sigma2      6.016e+09      0.772    7.8e+09      0.000    6.02e+09    6.02e+09
# ===================================================================================
# Ljung-Box (Q):                       64.07   Jarque-Bera (JB):                19.22
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.71   Skew:                            -0.48
# Prob(H) (two-sided):                  0.23   Kurtosis:                         4.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.96e+25. Standard errors may be unstable.
# """

# %%
train = df[:150]
test = df[150:]

fitted, confint = sxmodel.predict(n_periods=n_periods, 
                                  exogenous=np.tile(seasonal_index['Total'], 2).reshape(-1,1), 
                                  return_conf_int=True,alpha=0.05)

index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train['Total'], label ='Training')
plt.plot(test['Total'], label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMAX - Final Forecast of Motor Total Sales with Exogenous Variable")
plt.show()

# %%
fitted
# Out:
# array([539619.87989958, 524452.64850852, 592771.03083449, 612668.67184612,
#        627751.51335556, 513242.00767094, 629350.19511958, 628961.08955591,
#        626187.37227518, 662445.75678545, 643588.6137905 , 527357.82345561,
#        600655.51378076, 600998.91891276, 649407.20908703, 655212.04598496,
#        670340.08881519, 601267.25820416, 666848.24908055, 677082.57181463,
#        676728.71171146, 704272.06337708, 681832.81567865, 578229.95880497])

# %%
confint
# Out:
# array([[385800.91562411, 693438.84417506],
#        [359042.98458568, 689862.31243137],
#        [410268.46555299, 775273.59611599],
#        [423029.61994271, 802307.72374953],
#        [432369.78526744, 823133.24144369],
#        [314499.29682103, 711984.71852084],
#        [428263.19005815, 830437.200181  ],
#        [426370.72289321, 831551.45621861],
#        [422591.00515605, 829783.7393943 ],
#        [458193.72640298, 866697.78716793],
#        [438925.1136452 , 848252.11393581],
#        [322422.63833005, 732293.00858118],
#        [375926.95428174, 825384.07327978],
#        [372663.56699103, 829334.27083449],
#        [416101.15957277, 882713.2586013 ],
#        [419596.52999261, 890827.56197732],
#        [432880.20997318, 907799.96765721],
#        [362696.04705286, 839838.46935546],
#        [427505.7659943 , 906190.7321668 ],
#        [437247.91078047, 916917.23284879],
#        [436578.10177993, 916879.32164298],
#        [463928.63021004, 944615.49654411],
#        [441412.90525309, 922252.7261042 ],
#        [337761.32525561, 818698.59235433]])

# %%
#Import the usual library

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import warnings
warnings.filterwarnings('ignore')

# %%
dfhonda = pd.read_excel('Penjualan_Motor_20052018.xlsx', index_col = 0)

# %%
dfhonda.head()
# Out:
#              Honda  Yamaha  Suzuki  Kawasaki  Others   Total
# Periode
# 2005-01-01  208204   83114   83846      7701    4218  387083
# 2005-02-01  192320   78640   82381      6821    3244  363406
# 2005-03-01  217344   79752   96876      4147    2601  400720
# 2005-04-01  205691   94465  100507      3911    3170  407744
# 2005-05-01  219358  104530   87016      5496    3208  419608

# %%
dfhonda.tail()
# Out:
#              Honda  Yamaha  Suzuki  Kawasaki  Others   Total
# Periode
# 2018-08-01  443694  108896    8355      7016      95  568056
# 2018-09-01  406841  134419    9371      7036      25  557692
# 2018-10-01  456582  138012   10489      5212      27  610322
# 2018-11-01  440659  140683   10002      6003      17  597364
# 2018-12-01  325076  115033    8050      5003      19  453181

# %%
dfhonda.describe()
# Out:
#                Honda         Yamaha         Suzuki      Kawasaki       Others  \
# count     168.000000     168.000000     168.000000    168.000000   168.000000
# mean   310822.386905  175026.244048   35766.636905   7397.000000  1338.797619
# std     93246.421717   61626.397054   25450.456794   3786.507278  1224.451893
# min    116873.000000   78640.000000    1833.000000   1297.000000     4.000000
# 25%    235415.250000  123761.750000   10214.250000   4146.000000   187.000000
# 50%    324115.000000  162387.000000   35978.000000   7026.000000  1030.000000
# 75%    386756.000000  218053.750000   47638.250000   9753.000000  2214.500000
# max    471585.000000  319686.000000  115136.000000  17924.000000  4261.000000
#
#                Total
# count     168.000000
# mean   530351.065476
# std    116333.307429
# min    266618.000000
# 25%    442292.750000
# 50%    538213.000000
# 75%    622299.000000
# max    750829.000000

# %%
dfhonda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2005-01-01 to 2018-12-01
# Data columns (total 6 columns):
# Honda       168 non-null int64
# Yamaha      168 non-null int64
# Suzuki      168 non-null int64
# Kawasaki    168 non-null int64
# Others      168 non-null int64
# Total       168 non-null int64
# dtypes: int64(6)
# memory usage: 9.2 KB

# %%
plt.figure(figsize = (18,8))
plt.title('Motor Sales in Indonesia 2005-2018')

plt.plot(dfhonda['Honda'], label = 'Honda')
plt.plot(dfhonda['Yamaha'], label = 'Yamaha')
plt.plot(dfhonda['Suzuki'], label = 'Suzuki')
plt.plot(dfhonda['Kawasaki'], label = 'Kawasaki')
plt.plot(dfhonda['Others'], label = 'Others')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (18,8))
plt.title('Motor Sales in Indonesia 2005-2018')

plt.bar(height=sum(dfhonda['Honda']), x = 'Honda')
plt.bar(height=sum(dfhonda['Yamaha']), x = 'Yamaha')
plt.bar(height=sum(dfhonda['Suzuki']), x = 'Suzuki')
plt.bar(height=sum(dfhonda['Kawasaki']), x = 'Kawasaki')
plt.bar(height=sum(dfhonda['Others']), x = 'Others')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize = (18,2))
plt.plot(dfhonda['Honda'])
plt.title('Monthly Average of Motor honda Sale')
plt.ylabel('Penjualan Per Bulan');
plt.show()
plt.figure(figsize = (18,2))
plt.plot(dfhonda['Yamaha'])
plt.title('Monthly Average of Motor yamaha Sale')
plt.ylabel('Penjualan Per Bulan');
plt.show()
plt.figure(figsize = (18,2))
plt.plot(dfhonda['Suzuki'])
plt.title('Monthly Average of Motor suzuki Sale')
plt.ylabel('Penjualan Per Bulan');
plt.show()
plt.figure(figsize = (18,2))
plt.plot(dfhonda['Kawasaki'])
plt.title('Monthly Average of Motor kawasaki Sale')
plt.ylabel('Penjualan Per Bulan');
plt.show()
plt.figure(figsize = (18,2))
plt.plot(dfhonda['Others'])
plt.title('Monthly Average of Motor other Sale')
plt.ylabel('Penjualan Per Bulan');
plt.show()
plt.figure(figsize = (18,2))
plt.plot(dfhonda['Total'])
plt.title('Monthly Average of Motor total Sale')
plt.ylabel('Penjualan Per Bulan');
plt.show()

# %%
print('The data Time range from {} to {}'.format(dfhonda.index.min(),dfhonda.index.max()))
# Out:
# The data Time range from 2005-01-01 00:00:00 to 2018-12-01 00:00:00

# %%
y = dfhonda['Honda'].resample('MS').mean()

# %%
y
# Out:
# Periode
# 2005-01-01    208204
# 2005-02-01    192320
# 2005-03-01    217344
# 2005-04-01    205691
# 2005-05-01    219358
# 2005-06-01    241295
# 2005-07-01    238044
# 2005-08-01    256591
# 2005-09-01    237039
# 2005-10-01    283672
# 2005-11-01    188506
# 2005-12-01    160126
# 2006-01-01    116873
# 2006-02-01    167916
# 2006-03-01    145031
# 2006-04-01    140214
# 2006-05-01    170839
# 2006-06-01    171674
# 2006-07-01    186047
# 2006-08-01    241416
# 2006-09-01    276384
# 2006-10-01    174249
# 2006-11-01    293389
# 2006-12-01    255136
# 2007-01-01    153806
# 2007-02-01    150979
# 2007-03-01    151074
# 2007-04-01    138434
# 2007-05-01    169217
# 2007-06-01    159859
#                ...
# 2016-07-01    203659
# 2016-08-01    388847
# 2016-09-01    423256
# 2016-10-01    446611
# 2016-11-01    450331
# 2016-12-01    309796
# 2017-01-01    368739
# 2017-02-01    345921
# 2017-03-01    358524
# 2017-04-01    274155
# 2017-05-01    394751
# 2017-06-01    263854
# 2017-07-01    403487
# 2017-08-01    418931
# 2017-09-01    408116
# 2017-10-01    436974
# 2017-11-01    430487
# 2017-12-01    281949
# 2018-01-01    345957
# 2018-02-01    339152
# 2018-03-01    384187
# 2018-04-01    458499
# 2018-05-01    436727
# 2018-06-01    271206
# 2018-07-01    450622
# 2018-08-01    443694
# 2018-09-01    406841
# 2018-10-01    456582
# 2018-11-01    440659
# 2018-12-01    325076
# Freq: MS, Name: Honda, Length: 168, dtype: int64

# %%
y.head()
# Out:
# Periode
# 2005-01-01    208204
# 2005-02-01    192320
# 2005-03-01    217344
# 2005-04-01    205691
# 2005-05-01    219358
# Freq: MS, Name: Honda, dtype: int64

# %%
y.isna().any()
# Out:
# False

# %%
plt.figure(figsize = (18,8))
plt.title('Monthly Average of Motor honda Sale')
y.plot()

# EXPONENSIAL

# %%
plt.figure(figsize = (18,8))
plt.title('Monthly Average of Motor honda Sale')
y.plot(style = 'k.')

# %%
plt.figure(figsize = (18,8))
plt.title('Monthly Average of Motor honda Sale')
y.hist()

# %%
plt.figure(figsize = (18,8))
plt.title('Monthly Average of Motor honda Sale')
y.plot(kind = 'kde')

# %%
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='multipicative')
fig = decomposition.plot()
plt.show()

# %%
decomposition.trend
# Out:
# Periode
# 2005-01-01              NaN
# 2005-02-01              NaN
# 2005-03-01              NaN
# 2005-04-01              NaN
# 2005-05-01              NaN
# 2005-06-01              NaN
# 2005-07-01    216877.041667
# 2005-08-01    212054.750000
# 2005-09-01    208024.875000
# 2005-10-01    202283.625000
# 2005-11-01    197533.791667
# 2005-12-01    192611.291667
# 2006-01-01    187543.875000
# 2006-02-01    184745.041667
# 2006-03-01    185752.125000
# 2006-04-01    182832.208333
# 2006-05-01    182643.041667
# 2006-06-01    190971.916667
# 2006-07-01    196469.541667
# 2006-08-01    197302.708333
# 2006-09-01    196848.791667
# 2006-10-01    197026.416667
# 2006-11-01    196884.666667
# 2006-12-01    196324.791667
# 2007-01-01    194048.583333
# 2007-02-01    190015.500000
# 2007-03-01    186217.541667
# 2007-04-01    186329.125000
# 2007-05-01    185897.500000
# 2007-06-01    181112.125000
#                   ...
# 2016-07-01    368447.458333
# 2016-08-01    371123.125000
# 2016-09-01    367023.375000
# 2016-10-01    360518.458333
# 2016-11-01    359733.125000
# 2016-12-01    357210.541667
# 2017-01-01    360696.500000
# 2017-02-01    370276.166667
# 2017-03-01    370898.833333
# 2017-04-01    369866.458333
# 2017-05-01    368638.083333
# 2017-06-01    366650.958333
# 2017-07-01    364541.416667
# 2017-08-01    363310.125000
# 2017-09-01    364097.375000
# 2017-10-01    372847.666667
# 2017-11-01    382277.666667
# 2017-12-01    384333.000000
# 2018-01-01    386603.291667
# 2018-02-01    389599.041667
# 2018-03-01    390577.708333
# 2018-04-01    391341.583333
# 2018-05-01    392582.416667
# 2018-06-01    394803.208333
# 2018-07-01              NaN
# 2018-08-01              NaN
# 2018-09-01              NaN
# 2018-10-01              NaN
# 2018-11-01              NaN
# 2018-12-01              NaN
# Freq: MS, Name: Honda, Length: 168, dtype: float64

# %%
#import the Augmented Dickey-Fuller Test

from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(y)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-1.0658350767270597
# p-value: 0.7285024686772399

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})

# Original Series
ori = y.plot()
ori.set_title('Original Series')
plot_acf(y, title = 'Autocorellation original')

plt.show()

# %%
# 1st Differencing
diff1 = y.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_acf(y.diff().dropna(),lags =30,  title = 'Autocorellation Differenced 1')

plt.show()

# %%
# 2nd Differencing
diff2 = y.diff().diff().dropna().plot()
diff2.set_title('Time Series Differenced 2')
plot_acf(y.diff().diff().dropna(),lags = 30, title = 'Autocorellation Differenced 2')

plt.show()

# %%
# 12ve Differencing
diff12 = y.diff(12).dropna().plot()
diff12.set_title('Time Series Differenced 12')
plot_acf(y.diff(12).dropna(),lags = 30, title = 'Autocorellation Differenced 12')

plt.show()

# %%
result = adfuller(y.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-5.55999076509974
# p-value: 1.5496266231603961e-06

# %%
result = adfuller(y.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-8.527540460746284
# p-value: 1.0591484352146545e-13

# %%
result = adfuller(y.diff(12).dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-2.2950992412201323
# p-value: 0.1735534358168339

# %%
y_difference_2 = y.diff().diff().dropna()

# %%
decomposition_difference_2 = sm.tsa.seasonal_decompose(y_difference_2, model='additive') 
fig = decomposition_difference_2.plot()
plt.show()

# %%
y_deseason = y_difference_2/ decomposition_difference_2.seasonal

# %%
#Deseason original
ori_deseason = y_deseason.plot()
ori_deseason.set_title('Deseason Original')
plot_acf(y_deseason, title = 'Deseason original Autocorellation')

plt.show()

# %%
result = adfuller(y_deseason)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-12.681691707651131
# p-value: 1.1831804429472477e-23

# %%
# 1st Differencing
diff1_deseason = y_deseason.diff().dropna().plot()
diff1_deseason.set_title('Time Series Deseason Differenced 1')
plot_acf(y_deseason.diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 1')

plt.show()

# %%
result = adfuller(y_deseason.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-9.266233822274454
# p-value: 1.3646118195901451e-15

# %%
# 2nd Differencing
diff2_deseason = y_deseason.diff().diff().dropna().plot()
diff2_deseason.set_title('Time Series Deseason Differenced 2')
plot_acf(y_deseason.diff().diff().dropna(),lags = 30, title = 'Deseason Autocorellation Differenced 2')

plt.show()

# %%
result = adfuller(y_deseason.diff().diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-9.231825520311617
# p-value: 1.6703805814830443e-15

# %%
#PACF
diff1 = y_deseason.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_pacf(y_deseason.diff().dropna(), lags = 30, title = 'Partial Autocorellation Differenced 1')

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(y_deseason,order =(1,1,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Honda   No. Observations:                  165
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1076.047
# Method:                       css-mle   S.D. of innovations            161.923
# Date:                Fri, 22 Nov 2019   AIC                           2160.095
# Time:                        14:45:14   BIC                           2172.519
# Sample:                    04-01-2005   HQIC                          2165.138
#                          - 12-01-2018
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.2178      0.264      0.824      0.411      -0.301       0.736
# ar.L1.D.Honda     0.0085      0.078      0.109      0.913      -0.144       0.161
# ma.L1.D.Honda    -1.0000      0.021    -46.749      0.000      -1.042      -0.958
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          117.9016           +0.0000j          117.9016            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
plt.rcParams.update({'figure.figsize':(12,3), 'figure.dpi':120})
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
#Data split by close to 1:4 ratio

train = y_deseason[:125]
test = y_deseason[125:]

# %%
n_periods = 24
model = ARIMA(train, order=(1, 1, 1))  
fitted = model.fit(disp=-1)  

# Forecast (resulted in forecast, standard error, and confidence interval)
fc, se, conf = fitted.forecast(41, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    
    mins = np.amin(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
  
    return({'mape':mape,'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test)
# Out:
# {'mape': 37.1887311596949,
#  'corr': 0.13579724760021764,
#  'minmax': 1.7068281576837412}

# %%
import pmdarima as pm

model = pm.auto_arima(y_deseason, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series (1 as monthly)
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# C:\Users\FEBRIANRACHMAD\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# Fit ARIMA: order=(1, 0, 1); AIC=2167.687, BIC=2180.135, Fit time=0.096 seconds
# Fit ARIMA: order=(0, 0, 0); AIC=2163.697, BIC=2169.921, Fit time=0.002 seconds
# Fit ARIMA: order=(1, 0, 0); AIC=2165.689, BIC=2175.025, Fit time=0.020 seconds
# Fit ARIMA: order=(0, 0, 1); AIC=2165.689, BIC=2175.025, Fit time=0.008 seconds
# Total fit time: 0.129 seconds
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  166
# Model:                     ARMA(0, 0)   Log Likelihood               -1079.848
# Method:                           css   S.D. of innovations            161.770
# Date:                Fri, 22 Nov 2019   AIC                           2163.697
# Time:                        14:45:17   BIC                           2169.921
# Sample:                             0   HQIC                          2166.223
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2280     12.556      0.018      0.986     -24.381      24.837
# ==============================================================================

# %%
model.plot_diagnostics(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(y, label='Original Series')
axes[0].plot(y.diff(), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)

# Seasonal Differencing
axes[1].plot(y, label='Original Series')
axes[1].plot(y.diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('Motor Honda Sales', fontsize=16)
plt.show()

# %%
model = pm.auto_arima(y['Honda']['2015-01':'2018-12'], start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=5, max_q=5, # maximum p and q
                      m=12,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # with Seasonality
                      start_P=0, 
                      start_Q = 0, 
                      D=1,            #Determine the Seasonal Difference as 1
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=900.566, BIC=903.733, Fit time=0.011 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=902.290, BIC=908.624, Fit time=0.067 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=901.364, BIC=906.114, Fit time=0.025 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=901.408, BIC=906.158, Fit time=0.013 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=901.428, BIC=906.178, Fit time=0.015 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=903.377, BIC=909.711, Fit time=0.035 seconds
# Total fit time: 0.178 seconds
#                             Statespace Model Results
# ================================================================================
# Dep. Variable:                        y   No. Observations:                   48
# Model:             SARIMAX(0, 1, 0, 12)   Log Likelihood                -448.283
# Date:                  Fri, 22 Nov 2019   AIC                            900.566
# Time:                          15:20:27   BIC                            903.733
# Sample:                               0   HQIC                           901.671
#                                    - 48
# Covariance Type:                    opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   8480.9444    1.2e+04      0.708      0.479    -1.5e+04     3.2e+04
# sigma2      3.832e+09   7.19e+08      5.331      0.000    2.42e+09    5.24e+09
# ===================================================================================
# Ljung-Box (Q):                         nan   Jarque-Bera (JB):                14.26
# Prob(Q):                               nan   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.63   Skew:                             1.05
# Prob(H) (two-sided):                  0.41   Kurtosis:                         5.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
y['2015-01':'2018-12']
# Out:
#              Honda  month
# Periode
# 2015-01-01  339850      1
# 2015-02-01  376973      2
# 2015-03-01  376571      3
# 2015-04-01  371001      4
# 2015-05-01  304900      5
# 2015-06-01  361767      6
# 2015-07-01  278754      7
# 2015-08-01  430953      8
# 2015-09-01  425458      9
# 2015-10-01  453944     10
# 2015-11-01  394726     11
# 2015-12-01  338991     12
# 2016-01-01  287776      1
# 2016-02-01  362668      2
# 2016-03-01  440171      3
# 2016-04-01  348626      4
# 2016-05-01  339128      5
# 2016-06-01  380019      6
# 2016-07-01  203659      7
# 2016-08-01  388847      8
# 2016-09-01  423256      9
# 2016-10-01  446611     10
# 2016-11-01  450331     11
# 2016-12-01  309796     12
# 2017-01-01  368739      1
# 2017-02-01  345921      2
# 2017-03-01  358524      3
# 2017-04-01  274155      4
# 2017-05-01  394751      5
# 2017-06-01  263854      6
# 2017-07-01  403487      7
# 2017-08-01  418931      8
# 2017-09-01  408116      9
# 2017-10-01  436974     10
# 2017-11-01  430487     11
# 2017-12-01  281949     12
# 2018-01-01  345957      1
# 2018-02-01  339152      2
# 2018-03-01  384187      3
# 2018-04-01  458499      4
# 2018-05-01  436727      5
# 2018-06-01  271206      6
# 2018-07-01  450622      7
# 2018-08-01  443694      8
# 2018-09-01  406841      9
# 2018-10-01  456582     10
# 2018-11-01  440659     11
# 2018-12-01  325076     12

# %%
model.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
n_periods = 24
train = y[:125]
test = y[125:]

fitted, confint = model.predict(n_periods=n_periods, return_conf_int=True) #Return the Confidence Interval
index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train, label ='Training')
plt.plot(test, label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast of Motor Honda Sales")
plt.show()

# %%
fitted
# Out:
# array([390139.69758294, 398263.98987378, 433911.37988942, 461668.06921539,
#        460682.37507096, 379792.55100071, 459199.25618733, 473199.68270158,
#        464065.39880363, 494932.11788371, 481492.63111419, 388986.40652749,
#        436036.16811437, 446538.34917706, 473654.8266433 , 481648.18231854,
#        486737.75307404, 436727.89873432, 477753.92428007, 499211.81910847,
#        500243.57359378, 523818.69394219, 511200.13313373, 427317.21037643])

# %%
confint
# Out:
# array([[282903.46460302, 497375.93056287],
#        [286236.2576868 , 510291.72206077],
#        [317084.04218455, 550738.71759429],
#        [343597.95535447, 579738.18307631],
#        [341964.25252789, 579400.49761402],
#        [260839.77993144, 498745.32206998],
#        [340143.37219668, 578255.14017798],
#        [354103.08811859, 592296.27728457],
#        [344952.48921711, 583178.30839015],
#        [375813.92795719, 614050.30781022],
#        [362378.04549355, 600607.21673483],
#        [269876.92448911, 508095.88856588],
#        [306313.98765709, 565758.34857164],
#        [315870.00885422, 577206.68949991],
#        [342014.72118893, 605294.93209766],
#        [349749.91305491, 613546.45158217],
#        [354704.36284693, 618771.14330115],
#        [304645.44335478, 568810.35411386],
#        [345650.07893715, 609857.769623  ],
#        [367099.93321217, 631323.70500477],
#        [368129.63273785, 632357.51444971],
#        [391706.2544769 , 655931.13340748],
#        [379098.23298697, 643302.03328049],
#        [295225.7978417 , 559408.62291115]])

# %%
#Decompose the time series data to get the seasonal data. Lets try to take 36 months back in the past as exogenous variable

# multiplicative seasonal component
result_mul = sm.tsa.seasonal_decompose(y[-36:],   # 36 months
                                model='multiplicative', 
                                extrapolate_trend='freq')

# %%
plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})
fig = result_mul.plot()
plt.show()

# %%
#We would use what we called seasonal index as our exogenous varibale. We take the latest 12 month.
seasonal_index = result_mul.seasonal[-12:].to_frame()
seasonal_index['month'] = pd.to_datetime(seasonal_index.index).month

# %%
#lets merge it into one dataframe
y = pd.DataFrame(y)
y['month'] = y.index.month
df = pd.merge(y, seasonal_index, how='left', on='month')
df.columns = ['Honda', 'month', 'seasonal_index']
df.index = y.index  # reassign the index.

# %%
df.head()
# Out:
#              Honda  month  seasonal_index
# Periode
# 2005-01-01  208204      1        0.908384
# 2005-02-01  192320      2        0.939597
# 2005-03-01  217344      3        1.059620
# 2005-04-01  205691      4        0.962489
# 2005-05-01  219358      5        1.044225

# %%
sxmodel = pm.auto_arima(df[['Honda']], exogenous=df[['seasonal_index']],
                           start_p=1, start_q=1,
                           test='adf',
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=None, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)

sxmodel.summary()
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=3846.404, BIC=3864.703, Fit time=0.405 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=3892.365, BIC=3901.514, Fit time=0.014 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=3860.530, BIC=3875.779, Fit time=0.122 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=3863.649, BIC=3878.899, Fit time=0.137 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3840.302, BIC=3861.651, Fit time=0.430 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 0, 12); AIC=3853.611, BIC=3871.910, Fit time=0.213 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=3840.665, BIC=3865.064, Fit time=0.961 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=3868.408, BIC=3883.657, Fit time=0.097 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 1, 2, 12); AIC=3841.412, BIC=3868.861, Fit time=1.251 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3856.798, BIC=3875.097, Fit time=0.408 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3839.122, BIC=3863.521, Fit time=0.488 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=3837.662, BIC=3859.011, Fit time=0.474 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=3839.989, BIC=3867.438, Fit time=0.655 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=3845.850, BIC=3864.149, Fit time=0.174 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=3839.662, BIC=3864.061, Fit time=1.122 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=3852.013, BIC=3870.312, Fit time=0.220 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 2, 12); AIC=3839.653, BIC=3864.052, Fit time=1.091 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=3865.850, BIC=3881.099, Fit time=0.051 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 2, 12); AIC=3841.613, BIC=3869.062, Fit time=1.301 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=3844.697, BIC=3862.996, Fit time=0.399 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=3837.993, BIC=3862.392, Fit time=0.523 seconds
# Total fit time: 10.549 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  168
# Model:             SARIMAX(2, 0, 0)x(1, 1, 1, 12)   Log Likelihood               -1911.831
# Date:                            Fri, 22 Nov 2019   AIC                           3837.662
# Time:                                    14:45:42   BIC                           3859.011
# Sample:                                         0   HQIC                          3846.333
#                                             - 168
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   6769.5785   1754.536      3.858      0.000    3330.750    1.02e+04
# x1          2.635e-05   5.95e+04   4.43e-10      1.000   -1.17e+05    1.17e+05
# ar.L1          0.3025      0.100      3.031      0.002       0.107       0.498
# ar.L2          0.2178      0.088      2.473      0.013       0.045       0.390
# ar.S.L12       0.3769      0.144      2.617      0.009       0.095       0.659
# ma.S.L12      -0.9063      0.178     -5.095      0.000      -1.255      -0.558
# sigma2       2.97e+09      2.482    1.2e+09      0.000    2.97e+09    2.97e+09
# ===================================================================================
# Ljung-Box (Q):                       64.18   Jarque-Bera (JB):                 3.52
# Prob(Q):                              0.01   Prob(JB):                         0.17
# Heteroskedasticity (H):               1.53   Skew:                            -0.27
# Prob(H) (two-sided):                  0.13   Kurtosis:                         3.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.37e+24. Standard errors may be unstable.
# """

# %%
train = df[:150]
test = df[150:]

fitted, confint = sxmodel.predict(n_periods=n_periods, 
                                  exogenous=np.tile(seasonal_index['Honda'], 2).reshape(-1,1), 
                                  return_conf_int=True,alpha=0.05)

index_of_fc = pd.date_range(train.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (18,8))
plt.plot(train['Honda'], label ='Training')
plt.plot(test['Honda'], label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMAX - Final Forecast of Motor Honda Sales with Exogenous Variable")
plt.show()

# %%
fitted
# Out:
# array([390139.69767157, 398263.98994589, 433911.37991983, 461668.06928223,
#        460682.37514271, 379792.55121104, 459199.25633639, 473199.68277756,
#        464065.3988553 , 494932.11787179, 481492.63112677, 388986.40669207,
#        436036.1683011 , 446538.34934575, 473654.82672907, 481648.18241989,
#        486737.75318927, 436727.89908869, 477753.92448805, 499211.81922751,
#        500243.57369554, 523818.69394472, 511200.13317131, 427317.21063713])

# %%
confint
# Out:
# array([[282903.46467429, 497375.93066885],
#        [286236.25773985, 510291.72215192],
#        [317084.04220043, 550738.71763922],
#        [343597.95540797, 579738.1831565 ],
#        [341964.25258749, 579400.49769794],
#        [260839.78013011, 498745.32229197],
#        [340143.37233437, 578255.14033841],
#        [354103.08818334, 592296.27737177],
#        [344952.48925764, 583178.30845296],
#        [375813.92793421, 614050.30780938],
#        [362378.04549526, 600607.21675828],
#        [269876.92464299, 508095.88874115],
#        [306313.98786066, 565758.34874153],
#        [315870.00904176, 577206.68964973],
#        [342014.72129687, 605294.93216128],
#        [349749.91317931, 613546.45166048],
#        [354704.36298579, 618771.14339274],
#        [304645.44373302, 568810.35444437],
#        [345650.07916911, 609857.76980699],
#        [367099.93335526, 631323.70509975],
#        [368129.63286373, 632357.51452735],
#        [391706.25450363, 655931.1333858 ],
#        [379098.23304908, 643302.03329355],
#        [295225.79812724, 559408.62314701]])
